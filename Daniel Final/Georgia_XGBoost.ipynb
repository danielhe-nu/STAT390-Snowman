# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score,train_test_split,RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import GridSearchCV, ParameterGrid
import time as time

import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def mase(actual, forecast):
    n = len(actual)
    numerator = np.mean(np.abs(actual - forecast))
    denominator = np.mean(np.abs(np.diff(actual)))
    return numerator / denominator

# %%
covid_df = pd.read_csv('ohio_multi_df.csv', parse_dates=['Date'])
covid_df.drop(columns = ['PROVINCE_STATE_NAME'], inplace = True)
covid_df = covid_df.rename(columns={'Date': 'ds', 'PEOPLE_POSITIVE_NEW_CASES_COUNT': 'y'})
covid_df.set_index('ds', inplace=True)

train_size = int(len(covid_df)* 0.85)
covid_train, covid_test = covid_df[0:train_size], covid_df[train_size:]

# %%
covid_train = covid_train[['y', 'new_deaths_7_lag', 'new_deaths_50_lag', 'new_cases_10_std', 'new_cases_2_lag', 'new_cases_1 lag', 'new_cases_7_lag', 'relative_humidity', 'average_temperature_celsius', 'new_deaths_30_lag', 'new_cases_50_std', 'dew_point', 'new_deaths_100_std', 'new_deaths_4_lag', 'new_cases_10_mean', 'new_cases_3_lag', 'new_hospitalized_patients', 'new_deaths_2_lag', 'current_intensive_care_patients', 'new_cases_10_max', 'PEOPLE_DEATH_NEW_COUNT', 'new_deaths_3_lag', 'new_cases_4_lag', 'new_cases_10_min', 'new_deaths_1_lag', 'new_cases_150_lag']]
covid_test = covid_test[['y', 'new_deaths_7_lag', 'new_deaths_50_lag', 'new_cases_10_std', 'new_cases_2_lag', 'new_cases_1 lag', 'new_cases_7_lag', 'relative_humidity', 'average_temperature_celsius', 'new_deaths_30_lag', 'new_cases_50_std', 'dew_point', 'new_deaths_100_std', 'new_deaths_4_lag', 'new_cases_10_mean', 'new_cases_3_lag', 'new_hospitalized_patients', 'new_deaths_2_lag', 'current_intensive_care_patients', 'new_cases_10_max', 'PEOPLE_DEATH_NEW_COUNT', 'new_deaths_3_lag', 'new_cases_4_lag', 'new_cases_10_min', 'new_deaths_1_lag', 'new_cases_150_lag']]

# %%
X_train = covid_train.drop(columns=['y'], axis=1)
y_train = covid_train['y']
X_test = covid_test.drop(columns=['y'], axis=1)
y_test = covid_test['y']

# %%
reg_model = xgb.XGBRegressor(learning_rate=0.01,n_estimators=10000, early_stopping_rounds=10)
reg_model.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)], 
       verbose=True)
# Out:
# [0]	validation_0-rmse:4525.84349	validation_1-rmse:10800.46185
# [1]	validation_0-rmse:4484.72989	validation_1-rmse:10726.66672
# [2]	validation_0-rmse:4444.02766	validation_1-rmse:10653.70346
# [3]	validation_0-rmse:4403.73322	validation_1-rmse:10581.57208
# [4]	validation_0-rmse:4363.84197	validation_1-rmse:10510.24787
# [5]	validation_0-rmse:4324.35017	validation_1-rmse:10439.73328
# [6]	validation_0-rmse:4285.25354	validation_1-rmse:10370.03356
# [7]	validation_0-rmse:4246.54881	validation_1-rmse:10301.16371
# [8]	validation_0-rmse:4208.23044	validation_1-rmse:10233.13135
# [9]	validation_0-rmse:4170.29674	validation_1-rmse:10165.91484
# [10]	validation_0-rmse:4132.74118	validation_1-rmse:10099.43686
# [11]	validation_0-rmse:4095.56460	validation_1-rmse:10033.64841
# [12]	validation_0-rmse:4058.75862	validation_1-rmse:9968.36022
# [13]	validation_0-rmse:4022.32274	validation_1-rmse:9904.16203
# [14]	validation_0-rmse:3986.25319	validation_1-rmse:9840.35691
# [15]	validation_0-rmse:3950.54636	validation_1-rmse:9777.33666
# [16]	validation_0-rmse:3915.19977	validation_1-rmse:9715.30686
# [17]	validation_0-rmse:3880.20882	validation_1-rmse:9653.77253
# [18]	validation_0-rmse:3845.57074	validation_1-rmse:9593.03277
# [19]	validation_0-rmse:3811.27177	validation_1-rmse:9534.80357
# [20]	validation_0-rmse:3777.32132	validation_1-rmse:9475.24662
# [21]	validation_0-rmse:3743.71658	validation_1-rmse:9418.49441
# [22]	validation_0-rmse:3710.39759	validation_1-rmse:9360.50609
# [23]	validation_0-rmse:3677.50511	validation_1-rmse:9303.44393
# [24]	validation_0-rmse:3644.94665	validation_1-rmse:9247.21004
# [25]	validation_0-rmse:3612.71796	validation_1-rmse:9191.63127
# [26]	validation_0-rmse:3580.72560	validation_1-rmse:9138.44558
# [27]	validation_0-rmse:3549.13001	validation_1-rmse:9084.07933
# [28]	validation_0-rmse:3517.85760	validation_1-rmse:9030.50011
# [29]	validation_0-rmse:3486.89990	validation_1-rmse:8977.72026
# [30]	validation_0-rmse:3455.96833	validation_1-rmse:8926.86163
# [31]	validation_0-rmse:3425.62313	validation_1-rmse:8875.23705
# [32]	validation_0-rmse:3395.58564	validation_1-rmse:8824.37554
# [33]	validation_0-rmse:3365.85051	validation_1-rmse:8774.17457
# [34]	validation_0-rmse:3336.11000	validation_1-rmse:8725.99171
# [35]	validation_0-rmse:3307.01232	validation_1-rmse:8677.72031
# [36]	validation_0-rmse:3278.17873	validation_1-rmse:8630.11232
# [37]	validation_0-rmse:3249.29106	validation_1-rmse:8583.72417
# [38]	validation_0-rmse:3221.01923	validation_1-rmse:8537.43920
# [39]	validation_0-rmse:3193.03546	validation_1-rmse:8491.52495
# [40]	validation_0-rmse:3164.94433	validation_1-rmse:8444.99958
# [41]	validation_0-rmse:3137.50578	validation_1-rmse:8400.39763
# [42]	validation_0-rmse:3110.27865	validation_1-rmse:8356.99901
# [43]	validation_0-rmse:3083.40331	validation_1-rmse:8312.65231
# [44]	validation_0-rmse:3056.70300	validation_1-rmse:8268.65717
# [45]	validation_0-rmse:3030.33060	validation_1-rmse:8226.56640
# [46]	validation_0-rmse:3003.79335	validation_1-rmse:8183.32539
# [47]	validation_0-rmse:2977.87816	validation_1-rmse:8140.66188
# [48]	validation_0-rmse:2952.32178	validation_1-rmse:8098.58974
# [49]	validation_0-rmse:2926.88779	validation_1-rmse:8056.94522
# [50]	validation_0-rmse:2901.83201	validation_1-rmse:8016.09848
# [51]	validation_0-rmse:2876.90278	validation_1-rmse:7975.29183
# [52]	validation_0-rmse:2851.86175	validation_1-rmse:7937.96272
# [53]	validation_0-rmse:2827.21183	validation_1-rmse:7898.40079
# [54]	validation_0-rmse:2802.65306	validation_1-rmse:7862.08341
# [55]	validation_0-rmse:2778.33935	validation_1-rmse:7826.02579
# [56]	validation_0-rmse:2754.26791	validation_1-rmse:7790.47587
# [57]	validation_0-rmse:2730.43624	validation_1-rmse:7755.42089
# [58]	validation_0-rmse:2706.93780	validation_1-rmse:7718.35717
# [59]	validation_0-rmse:2683.56311	validation_1-rmse:7684.95557
# [60]	validation_0-rmse:2660.42023	validation_1-rmse:7651.56085
# [61]	validation_0-rmse:2637.50717	validation_1-rmse:7618.64573
# [62]	validation_0-rmse:2614.89400	validation_1-rmse:7583.94116
# [63]	validation_0-rmse:2592.42082	validation_1-rmse:7551.93184
# [64]	validation_0-rmse:2570.17173	validation_1-rmse:7520.38412
# [65]	validation_0-rmse:2548.20323	validation_1-rmse:7486.65285
# [66]	validation_0-rmse:2526.39871	validation_1-rmse:7456.35002
# [67]	validation_0-rmse:2504.81394	validation_1-rmse:7426.12786
# [68]	validation_0-rmse:2483.59951	validation_1-rmse:7394.60962
# [69]	validation_0-rmse:2462.40389	validation_1-rmse:7365.57138
# [70]	validation_0-rmse:2441.33305	validation_1-rmse:7336.64896
# [71]	validation_0-rmse:2420.32895	validation_1-rmse:7305.57233
# [72]	validation_0-rmse:2399.65943	validation_1-rmse:7277.45149
# [73]	validation_0-rmse:2379.05821	validation_1-rmse:7247.56862
# [74]	validation_0-rmse:2358.82647	validation_1-rmse:7220.25144
# [75]	validation_0-rmse:2338.60158	validation_1-rmse:7191.09710
# [76]	validation_0-rmse:2318.76493	validation_1-rmse:7164.85811
# [77]	validation_0-rmse:2298.93511	validation_1-rmse:7136.39729
# [78]	validation_0-rmse:2279.55878	validation_1-rmse:7112.62976
# [79]	validation_0-rmse:2260.20857	validation_1-rmse:7084.80402
# [80]	validation_0-rmse:2240.87016	validation_1-rmse:7070.61552
# [81]	validation_0-rmse:2222.02758	validation_1-rmse:7047.97914
# [82]	validation_0-rmse:2203.22184	validation_1-rmse:7023.21101
# [83]	validation_0-rmse:2184.46472	validation_1-rmse:6999.18906
# [84]	validation_0-rmse:2166.16290	validation_1-rmse:6975.48924
# [85]	validation_0-rmse:2147.76558	validation_1-rmse:6951.99465
# [86]	validation_0-rmse:2129.80376	validation_1-rmse:6930.97584
# [87]	validation_0-rmse:2111.75759	validation_1-rmse:6908.17069
# [88]	validation_0-rmse:2094.00786	validation_1-rmse:6883.71157
# [89]	validation_0-rmse:2076.56435	validation_1-rmse:6863.63231
# [90]	validation_0-rmse:2059.02784	validation_1-rmse:6841.82224
# [91]	validation_0-rmse:2041.87045	validation_1-rmse:6820.23897
# [92]	validation_0-rmse:2024.64165	validation_1-rmse:6797.47236
# [93]	validation_0-rmse:2007.72810	validation_1-rmse:6776.50887
# [94]	validation_0-rmse:1991.07860	validation_1-rmse:6755.93789
# [95]	validation_0-rmse:1974.42956	validation_1-rmse:6735.64656
# [96]	validation_0-rmse:1957.95222	validation_1-rmse:6713.87125
# [97]	validation_0-rmse:1941.64129	validation_1-rmse:6696.23433
# [98]	validation_0-rmse:1925.39519	validation_1-rmse:6676.35060
# [99]	validation_0-rmse:1909.38777	validation_1-rmse:6656.42785
# [100]	validation_0-rmse:1893.43353	validation_1-rmse:6637.72795
# [101]	validation_0-rmse:1877.73063	validation_1-rmse:6620.20068
# [102]	validation_0-rmse:1862.16937	validation_1-rmse:6603.08861
# [103]	validation_0-rmse:1846.68197	validation_1-rmse:6582.77955
# [104]	validation_0-rmse:1831.42808	validation_1-rmse:6566.09264
# [105]	validation_0-rmse:1816.10423	validation_1-rmse:6556.14171
# [106]	validation_0-rmse:1801.15370	validation_1-rmse:6539.90612
# [107]	validation_0-rmse:1786.36359	validation_1-rmse:6523.84556
# [108]	validation_0-rmse:1771.70713	validation_1-rmse:6506.46292
# [109]	validation_0-rmse:1757.01847	validation_1-rmse:6489.94757
# [110]	validation_0-rmse:1742.64856	validation_1-rmse:6474.62403
# [111]	validation_0-rmse:1728.18156	validation_1-rmse:6458.82926
# [112]	validation_0-rmse:1714.05801	validation_1-rmse:6442.58795
# [113]	validation_0-rmse:1699.91959	validation_1-rmse:6427.15692
# [114]	validation_0-rmse:1686.08523	validation_1-rmse:6412.81752
# [115]	validation_0-rmse:1672.20475	validation_1-rmse:6397.32256
# [116]	validation_0-rmse:1658.46415	validation_1-rmse:6382.64374
# [117]	validation_0-rmse:1644.84632	validation_1-rmse:6369.22712
# [118]	validation_0-rmse:1631.35135	validation_1-rmse:6355.23193
# [119]	validation_0-rmse:1617.99395	validation_1-rmse:6339.60650
# [120]	validation_0-rmse:1604.76559	validation_1-rmse:6326.15086
# [121]	validation_0-rmse:1591.83254	validation_1-rmse:6313.66306
# [122]	validation_0-rmse:1578.84668	validation_1-rmse:6301.50490
# [123]	validation_0-rmse:1565.95767	validation_1-rmse:6286.86957
# [124]	validation_0-rmse:1553.21874	validation_1-rmse:6274.96568
# [125]	validation_0-rmse:1540.59792	validation_1-rmse:6262.50521
# [126]	validation_0-rmse:1528.10263	validation_1-rmse:6250.24873
# [127]	validation_0-rmse:1515.70950	validation_1-rmse:6236.52021
# [128]	validation_0-rmse:1503.39799	validation_1-rmse:6224.73755
# [129]	validation_0-rmse:1491.40700	validation_1-rmse:6213.75466
# [130]	validation_0-rmse:1479.37038	validation_1-rmse:6203.06449
# [131]	validation_0-rmse:1467.42178	validation_1-rmse:6190.21221
# [132]	validation_0-rmse:1455.63365	validation_1-rmse:6179.07242
# [133]	validation_0-rmse:1443.90064	validation_1-rmse:6168.34950
# [134]	validation_0-rmse:1432.33652	validation_1-rmse:6155.73367
# [135]	validation_0-rmse:1420.79242	validation_1-rmse:6145.36115
# [136]	validation_0-rmse:1409.45236	validation_1-rmse:6134.68114
# [137]	validation_0-rmse:1398.32593	validation_1-rmse:6125.33191
# [138]	validation_0-rmse:1387.15660	validation_1-rmse:6114.61182
# [139]	validation_0-rmse:1376.04154	validation_1-rmse:6105.02752
# [140]	validation_0-rmse:1365.19557	validation_1-rmse:6095.13275
# [141]	validation_0-rmse:1354.32449	validation_1-rmse:6085.83525
# [142]	validation_0-rmse:1343.61403	validation_1-rmse:6074.76434
# [143]	validation_0-rmse:1333.01008	validation_1-rmse:6065.32227
# [144]	validation_0-rmse:1322.59402	validation_1-rmse:6056.96157
# [145]	validation_0-rmse:1312.09269	validation_1-rmse:6047.13806
# [146]	validation_0-rmse:1301.84667	validation_1-rmse:6037.70867
# [147]	validation_0-rmse:1291.58140	validation_1-rmse:6035.07044
# [148]	validation_0-rmse:1281.36803	validation_1-rmse:6032.49336
# [149]	validation_0-rmse:1271.42324	validation_1-rmse:6024.99843
# [150]	validation_0-rmse:1261.49266	validation_1-rmse:6017.03669
# [151]	validation_0-rmse:1251.57480	validation_1-rmse:6014.29631
# [152]	validation_0-rmse:1241.83591	validation_1-rmse:6006.58988
# [153]	validation_0-rmse:1232.10630	validation_1-rmse:6004.46882
# [154]	validation_0-rmse:1222.56351	validation_1-rmse:5996.20178
# [155]	validation_0-rmse:1212.99307	validation_1-rmse:5988.92726
# [156]	validation_0-rmse:1203.68143	validation_1-rmse:5982.22975
# [157]	validation_0-rmse:1194.36974	validation_1-rmse:5980.35463
# [158]	validation_0-rmse:1185.09851	validation_1-rmse:5978.46362
# [159]	validation_0-rmse:1176.04787	validation_1-rmse:5972.03254
# [160]	validation_0-rmse:1167.03680	validation_1-rmse:5970.21828
# [161]	validation_0-rmse:1157.95846	validation_1-rmse:5963.55542
# [162]	validation_0-rmse:1149.17787	validation_1-rmse:5956.26196
# [163]	validation_0-rmse:1140.28383	validation_1-rmse:5954.45207
# [164]	validation_0-rmse:1131.61441	validation_1-rmse:5952.90975
# [165]	validation_0-rmse:1123.09256	validation_1-rmse:5947.09057
# [166]	validation_0-rmse:1114.65781	validation_1-rmse:5941.38360
# [167]	validation_0-rmse:1106.14169	validation_1-rmse:5939.97026
# [168]	validation_0-rmse:1097.80412	validation_1-rmse:5938.29890
# [169]	validation_0-rmse:1089.60784	validation_1-rmse:5932.97250
# [170]	validation_0-rmse:1081.23198	validation_1-rmse:5931.38254
# [171]	validation_0-rmse:1073.20347	validation_1-rmse:5926.26043
# [172]	validation_0-rmse:1065.04911	validation_1-rmse:5919.45787
# [173]	validation_0-rmse:1057.14945	validation_1-rmse:5914.36717
# [174]	validation_0-rmse:1049.17492	validation_1-rmse:5913.36145
# [175]	validation_0-rmse:1041.38079	validation_1-rmse:5912.23779
# [176]	validation_0-rmse:1033.72360	validation_1-rmse:5909.37784
# [177]	validation_0-rmse:1025.93597	validation_1-rmse:5906.10764
# [178]	validation_0-rmse:1018.42596	validation_1-rmse:5903.31833
# [179]	validation_0-rmse:1010.93274	validation_1-rmse:5902.48438
# [180]	validation_0-rmse:1003.56115	validation_1-rmse:5899.79514
# [181]	validation_0-rmse:996.27456	validation_1-rmse:5897.33634
# [182]	validation_0-rmse:988.85224	validation_1-rmse:5894.20764
# [183]	validation_0-rmse:981.54736	validation_1-rmse:5893.31721
# [184]	validation_0-rmse:974.27492	validation_1-rmse:5890.33148
# [185]	validation_0-rmse:967.23863	validation_1-rmse:5887.96527
# [186]	validation_0-rmse:960.07656	validation_1-rmse:5883.30592
# [187]	validation_0-rmse:953.01023	validation_1-rmse:5880.46517
# [188]	validation_0-rmse:946.00043	validation_1-rmse:5877.63576
# [189]	validation_0-rmse:939.03544	validation_1-rmse:5873.29236
# [190]	validation_0-rmse:932.07536	validation_1-rmse:5872.31206
# [191]	validation_0-rmse:925.41690	validation_1-rmse:5870.08170
# [192]	validation_0-rmse:918.65283	validation_1-rmse:5867.42678
# [193]	validation_0-rmse:912.14280	validation_1-rmse:5865.32683
# [194]	validation_0-rmse:905.50184	validation_1-rmse:5862.82015
# [195]	validation_0-rmse:899.11283	validation_1-rmse:5860.80455
# [196]	validation_0-rmse:892.62700	validation_1-rmse:5858.39326
# [197]	validation_0-rmse:886.34224	validation_1-rmse:5855.02690
# [198]	validation_0-rmse:880.00333	validation_1-rmse:5854.52673
# [199]	validation_0-rmse:873.96140	validation_1-rmse:5852.54025
# [200]	validation_0-rmse:867.53311	validation_1-rmse:5850.94240
# [201]	validation_0-rmse:861.50296	validation_1-rmse:5849.19138
# [202]	validation_0-rmse:855.20146	validation_1-rmse:5847.62489
# [203]	validation_0-rmse:848.95777	validation_1-rmse:5846.40837
# [204]	validation_0-rmse:842.94267	validation_1-rmse:5846.45905
# [205]	validation_0-rmse:837.04827	validation_1-rmse:5841.26905
# [206]	validation_0-rmse:830.96650	validation_1-rmse:5839.99417
# [207]	validation_0-rmse:825.23595	validation_1-rmse:5834.85736
# [208]	validation_0-rmse:819.52809	validation_1-rmse:5833.41519
# [209]	validation_0-rmse:813.95720	validation_1-rmse:5832.03826
# [210]	validation_0-rmse:808.31333	validation_1-rmse:5830.19121
# [211]	validation_0-rmse:802.71279	validation_1-rmse:5828.52898
# [212]	validation_0-rmse:797.23047	validation_1-rmse:5823.74319
# [213]	validation_0-rmse:791.86593	validation_1-rmse:5822.49217
# [214]	validation_0-rmse:786.43384	validation_1-rmse:5820.89181
# [215]	validation_0-rmse:781.07151	validation_1-rmse:5818.54232
# [216]	validation_0-rmse:775.73331	validation_1-rmse:5817.00315
# [217]	validation_0-rmse:770.47880	validation_1-rmse:5815.94287
# [218]	validation_0-rmse:765.30110	validation_1-rmse:5811.49064
# [219]	validation_0-rmse:760.06595	validation_1-rmse:5807.16733
# [220]	validation_0-rmse:754.94112	validation_1-rmse:5805.83828
# [221]	validation_0-rmse:749.83878	validation_1-rmse:5803.36842
# [222]	validation_0-rmse:744.84097	validation_1-rmse:5802.42133
# [223]	validation_0-rmse:739.62747	validation_1-rmse:5801.82844
# [224]	validation_0-rmse:734.69670	validation_1-rmse:5799.49240
# [225]	validation_0-rmse:729.72595	validation_1-rmse:5796.58639
# [226]	validation_0-rmse:724.90823	validation_1-rmse:5795.77649
# [227]	validation_0-rmse:720.09528	validation_1-rmse:5793.97175
# [228]	validation_0-rmse:715.37213	validation_1-rmse:5792.74040
# [229]	validation_0-rmse:710.68380	validation_1-rmse:5791.14668
# [230]	validation_0-rmse:705.97224	validation_1-rmse:5788.47538
# [231]	validation_0-rmse:701.33461	validation_1-rmse:5787.00361
# [232]	validation_0-rmse:696.79805	validation_1-rmse:5785.85368
# [233]	validation_0-rmse:692.29402	validation_1-rmse:5784.86954
# [234]	validation_0-rmse:687.81312	validation_1-rmse:5783.45001
# [235]	validation_0-rmse:683.37773	validation_1-rmse:5782.03574
# [236]	validation_0-rmse:679.01615	validation_1-rmse:5781.03228
# [237]	validation_0-rmse:674.57890	validation_1-rmse:5778.59602
# [238]	validation_0-rmse:670.25188	validation_1-rmse:5775.79427
# [239]	validation_0-rmse:665.95650	validation_1-rmse:5772.87175
# [240]	validation_0-rmse:661.63428	validation_1-rmse:5770.55579
# [241]	validation_0-rmse:657.43082	validation_1-rmse:5767.84700
# [242]	validation_0-rmse:653.27179	validation_1-rmse:5765.08065
# [243]	validation_0-rmse:649.15810	validation_1-rmse:5762.52878
# [244]	validation_0-rmse:644.99181	validation_1-rmse:5760.37008
# [245]	validation_0-rmse:640.96262	validation_1-rmse:5757.79273
# [246]	validation_0-rmse:636.95831	validation_1-rmse:5755.23532
# [247]	validation_0-rmse:632.99821	validation_1-rmse:5752.73561
# [248]	validation_0-rmse:628.88363	validation_1-rmse:5750.46711
# [249]	validation_0-rmse:625.01227	validation_1-rmse:5748.17634
# [250]	validation_0-rmse:621.16374	validation_1-rmse:5747.17129
# [251]	validation_0-rmse:617.15018	validation_1-rmse:5745.20548
# [252]	validation_0-rmse:613.25600	validation_1-rmse:5743.29228
# [253]	validation_0-rmse:609.51564	validation_1-rmse:5742.40752
# [254]	validation_0-rmse:605.80587	validation_1-rmse:5741.41612
# [255]	validation_0-rmse:602.14829	validation_1-rmse:5740.67759
# [256]	validation_0-rmse:598.41484	validation_1-rmse:5739.60206
# [257]	validation_0-rmse:594.81069	validation_1-rmse:5738.72029
# [258]	validation_0-rmse:591.23493	validation_1-rmse:5737.86925
# [259]	validation_0-rmse:587.56747	validation_1-rmse:5736.14895
# [260]	validation_0-rmse:584.07016	validation_1-rmse:5735.46523
# [261]	validation_0-rmse:580.33334	validation_1-rmse:5733.63111
# [262]	validation_0-rmse:576.70442	validation_1-rmse:5732.25098
# [263]	validation_0-rmse:573.11964	validation_1-rmse:5730.88151
# [264]	validation_0-rmse:569.71757	validation_1-rmse:5730.25146
# [265]	validation_0-rmse:566.10834	validation_1-rmse:5728.52285
# [266]	validation_0-rmse:562.61459	validation_1-rmse:5727.26673
# [267]	validation_0-rmse:559.23083	validation_1-rmse:5726.71444
# [268]	validation_0-rmse:555.88319	validation_1-rmse:5726.19272
# [269]	validation_0-rmse:552.57144	validation_1-rmse:5725.69948
# [270]	validation_0-rmse:549.29514	validation_1-rmse:5725.23586
# [271]	validation_0-rmse:546.05640	validation_1-rmse:5724.80042
# [272]	validation_0-rmse:542.82771	validation_1-rmse:5724.39232
# [273]	validation_0-rmse:539.66808	validation_1-rmse:5724.01232
# [274]	validation_0-rmse:536.19580	validation_1-rmse:5723.46101
# [275]	validation_0-rmse:533.05619	validation_1-rmse:5723.13088
# [276]	validation_0-rmse:529.64476	validation_1-rmse:5722.63447
# [277]	validation_0-rmse:526.26639	validation_1-rmse:5722.16623
# [278]	validation_0-rmse:522.90252	validation_1-rmse:5721.73810
# [279]	validation_0-rmse:519.59345	validation_1-rmse:5721.32972
# [280]	validation_0-rmse:516.31208	validation_1-rmse:5720.96351
# [281]	validation_0-rmse:513.35654	validation_1-rmse:5720.77078
# [282]	validation_0-rmse:510.11427	validation_1-rmse:5720.44953
# [283]	validation_0-rmse:506.92385	validation_1-rmse:5720.14647
# [284]	validation_0-rmse:503.74511	validation_1-rmse:5719.88098
# [285]	validation_0-rmse:500.62054	validation_1-rmse:5719.64539
# [286]	validation_0-rmse:497.68045	validation_1-rmse:5718.81374
# [287]	validation_0-rmse:494.60011	validation_1-rmse:5718.61455
# [288]	validation_0-rmse:491.55094	validation_1-rmse:5718.45826
# [289]	validation_0-rmse:488.68968	validation_1-rmse:5717.69729
# [290]	validation_0-rmse:485.72048	validation_1-rmse:5717.56632
# [291]	validation_0-rmse:482.73280	validation_1-rmse:5717.46602
# [292]	validation_0-rmse:479.79825	validation_1-rmse:5717.39607
# [293]	validation_0-rmse:477.03665	validation_1-rmse:5716.73390
# [294]	validation_0-rmse:474.16249	validation_1-rmse:5716.58752
# [295]	validation_0-rmse:471.32183	validation_1-rmse:5716.45249
# [296]	validation_0-rmse:468.50511	validation_1-rmse:5716.34245
# [297]	validation_0-rmse:465.72168	validation_1-rmse:5716.24306
# [298]	validation_0-rmse:462.96515	validation_1-rmse:5716.15970
# [299]	validation_0-rmse:460.23507	validation_1-rmse:5716.12706
# [300]	validation_0-rmse:457.66816	validation_1-rmse:5715.65016
# [301]	validation_0-rmse:454.98150	validation_1-rmse:5715.74307
# [302]	validation_0-rmse:452.30225	validation_1-rmse:5715.87782
# [303]	validation_0-rmse:449.68404	validation_1-rmse:5715.88103
# [304]	validation_0-rmse:447.07494	validation_1-rmse:5715.93368
# [305]	validation_0-rmse:444.61010	validation_1-rmse:5715.52530
# [306]	validation_0-rmse:442.04983	validation_1-rmse:5715.60786
# [307]	validation_0-rmse:439.51025	validation_1-rmse:5715.70533
# [308]	validation_0-rmse:437.00983	validation_1-rmse:5715.74268
# [309]	validation_0-rmse:434.52347	validation_1-rmse:5715.88256
# [310]	validation_0-rmse:432.06885	validation_1-rmse:5715.97403
# [311]	validation_0-rmse:429.62059	validation_1-rmse:5716.10046
# [312]	validation_0-rmse:427.37064	validation_1-rmse:5715.79773
# [313]	validation_0-rmse:424.97320	validation_1-rmse:5715.98635
# [314]	validation_0-rmse:422.61223	validation_1-rmse:5716.08848
# [315]	validation_0-rmse:420.28078	validation_1-rmse:5716.21919
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=10,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=10000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
_ = plot_importance(reg_model, height=0.9 ,max_num_features = 10)

# %%
covid_test['forecast'] = reg_model.predict(X_test)

prophet_df_multi = pd.DataFrame(covid_df)

prophet_df_multi['forecast']=covid_test['forecast']

prophet_df_multi[['y', 'forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
graph_df = pd.DataFrame(covid_test)
graph_df['yhat'] = covid_test['forecast'].values
graph_df[['y','yhat']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
model_rmse = mean_squared_error(covid_test['y'], covid_test['forecast'], squared=False)
model_mae = mean_absolute_error(covid_test['y'], covid_test['forecast'])
print('Test RMSE: ', model_rmse)
print('Test MAE: ', model_mae)
print('MASE = ', mase(covid_test['y'], covid_test['forecast']))
# Out:
# Test RMSE:  5715.525279801411
# Test MAE:  2856.8363392292954
# MASE =  1.2089176547572416

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5, test_size = 100, gap = 1)
covid_df = covid_df.sort_index()

# %%
fig, axs = plt.subplots(5, 1, figsize=(10, 10), sharex=True)

fold = 0
for train_idx, val_idx in tss.split(covid_train):
    train = covid_df.iloc[train_idx]
    test = covid_df.iloc[val_idx]
    train['y'].plot(ax=axs[fold],
                          label='Training Set',
                          title=f'Data Train/Test Split Fold {fold}')
    test['y'].plot(ax=axs[fold],
                         label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold += 1
plt.show()

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=100, gap=1)
covid_df = covid_df.sort_index()


fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(covid_train):
    train = covid_df.iloc[train_idx]
    test = covid_df.iloc[val_idx]
    TARGET = 'y'

    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=1000,
                           early_stopping_rounds=20,
                           objective='reg:linear',
                           max_depth=3,
                           learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)

    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
# Out:
# [19:47:09] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1174.42496	validation_1-rmse:5454.09203
# [300]	validation_0-rmse:851.55468	validation_1-rmse:5279.03252
# [365]	validation_0-rmse:759.00973	validation_1-rmse:5280.76349
# [19:47:10] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1174.42496	validation_1-rmse:5454.09203
# [300]	validation_0-rmse:851.55468	validation_1-rmse:5279.03252
# [366]	validation_0-rmse:757.99933	validation_1-rmse:5279.31302
# [19:47:10] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1174.42496	validation_1-rmse:5454.09203
# [300]	validation_0-rmse:851.55468	validation_1-rmse:5279.03252
# [365]	validation_0-rmse:759.00973	validation_1-rmse:5280.76349
# [19:47:11] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1174.42496	validation_1-rmse:5454.09203
# [300]	validation_0-rmse:851.55468	validation_1-rmse:5279.03252
# [366]	validation_0-rmse:757.99933	validation_1-rmse:5279.31302
# [19:47:11] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1174.42496	validation_1-rmse:5454.09203
# [300]	validation_0-rmse:851.55468	validation_1-rmse:5279.03252
# [365]	validation_0-rmse:759.00973	validation_1-rmse:5280.76349

# %%
covid_test['forecast_1'] = reg.predict(X_test)

prophet_df_multi = pd.DataFrame(covid_df)

prophet_df_multi['forecast_1']=covid_test['forecast_1']

prophet_df_multi[['y', 'forecast_1']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
graph_df = pd.DataFrame(covid_test)
graph_df['yhat'] = covid_test['forecast_1'].values
graph_df[['y','yhat']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
model_rmse = mean_squared_error(covid_test['y'], covid_test['forecast'], squared=False)
model_mae = mean_absolute_error(covid_test['y'], covid_test['forecast'])
print('Test RMSE: ', model_rmse)
print('Test MAE: ', model_mae)
print('MASE = ', mase(covid_test['y'], covid_test['forecast']))
# Out:
# Test RMSE:  5715.525279801411
# Test MAE:  2856.8363392292954
# MASE =  1.2089176547572416
