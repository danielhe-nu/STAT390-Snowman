# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import cross_val_score,train_test_split,RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import GridSearchCV, ParameterGrid
import time as time

import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def mase(actual, forecast):
    n = len(actual)
    numerator = np.mean(np.abs(actual - forecast))
    denominator = np.mean(np.abs(np.diff(actual)))
    return numerator / denominator

# %%
covid_df = pd.read_csv('ohio_multi_df.csv', parse_dates=['Date'])
covid_df.drop(columns = ['PROVINCE_STATE_NAME'], inplace = True)
covid_df = covid_df.rename(columns={'Date': 'ds', 'PEOPLE_POSITIVE_NEW_CASES_COUNT': 'y'})
covid_df.set_index('ds', inplace=True)

train_size = int(len(covid_df)* 0.85)
covid_train, covid_test = covid_df[0:train_size], covid_df[train_size:]

# %%
covid_train = covid_train[['y', 'new_deaths_7_lag', 'new_deaths_50_lag', 'new_cases_10_std', 'new_cases_2_lag', 'new_cases_1 lag', 'new_cases_7_lag', 'relative_humidity', 'average_temperature_celsius', 'new_deaths_30_lag', 'new_cases_50_std', 'dew_point', 'new_deaths_100_std', 'new_deaths_4_lag', 'new_cases_10_mean', 'new_cases_3_lag', 'new_hospitalized_patients', 'new_deaths_2_lag', 'current_intensive_care_patients', 'new_cases_10_max', 'PEOPLE_DEATH_NEW_COUNT', 'new_deaths_3_lag', 'new_cases_4_lag', 'new_cases_10_min', 'new_deaths_1_lag', 'new_cases_150_lag']]
covid_test = covid_test[['y', 'new_deaths_7_lag', 'new_deaths_50_lag', 'new_cases_10_std', 'new_cases_2_lag', 'new_cases_1 lag', 'new_cases_7_lag', 'relative_humidity', 'average_temperature_celsius', 'new_deaths_30_lag', 'new_cases_50_std', 'dew_point', 'new_deaths_100_std', 'new_deaths_4_lag', 'new_cases_10_mean', 'new_cases_3_lag', 'new_hospitalized_patients', 'new_deaths_2_lag', 'current_intensive_care_patients', 'new_cases_10_max', 'PEOPLE_DEATH_NEW_COUNT', 'new_deaths_3_lag', 'new_cases_4_lag', 'new_cases_10_min', 'new_deaths_1_lag', 'new_cases_150_lag']]

# %%
X_train = covid_train.drop(columns=['y'], axis=1)
y_train = covid_train['y']
X_test = covid_test.drop(columns=['y'], axis=1)
y_test = covid_test['y']

# %%
reg_model = xgb.XGBRegressor(learning_rate=0.01,n_estimators=10000, early_stopping_rounds=10)
reg_model.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)], 
       verbose=True)
# Out:
# [0]	validation_0-rmse:4525.84349	validation_1-rmse:10800.46185
# [1]	validation_0-rmse:4484.72989	validation_1-rmse:10726.66672
# [2]	validation_0-rmse:4444.02766	validation_1-rmse:10653.67435
# [3]	validation_0-rmse:4403.73329	validation_1-rmse:10581.54306
# [4]	validation_0-rmse:4363.84206	validation_1-rmse:10510.18996
# [5]	validation_0-rmse:4324.35031	validation_1-rmse:10439.67530
# [6]	validation_0-rmse:4285.25376	validation_1-rmse:10369.94702
# [7]	validation_0-rmse:4246.54914	validation_1-rmse:10301.07914
# [8]	validation_0-rmse:4208.23076	validation_1-rmse:10233.01840
# [9]	validation_0-rmse:4170.29717	validation_1-rmse:10165.79868
# [10]	validation_0-rmse:4132.74158	validation_1-rmse:10099.29505
# [11]	validation_0-rmse:4095.56480	validation_1-rmse:10033.50136
# [12]	validation_0-rmse:4058.75898	validation_1-rmse:9968.21940
# [13]	validation_0-rmse:4022.32305	validation_1-rmse:9904.01047
# [14]	validation_0-rmse:3986.25366	validation_1-rmse:9840.21147
# [15]	validation_0-rmse:3950.54693	validation_1-rmse:9777.19737
# [16]	validation_0-rmse:3915.20027	validation_1-rmse:9715.17686
# [17]	validation_0-rmse:3880.20921	validation_1-rmse:9653.64901
# [18]	validation_0-rmse:3845.57130	validation_1-rmse:9592.91550
# [19]	validation_0-rmse:3811.27231	validation_1-rmse:9534.68575
# [20]	validation_0-rmse:3777.32205	validation_1-rmse:9475.13507
# [21]	validation_0-rmse:3743.71748	validation_1-rmse:9418.38915
# [22]	validation_0-rmse:3710.39850	validation_1-rmse:9360.40116
# [23]	validation_0-rmse:3677.50621	validation_1-rmse:9303.34529
# [24]	validation_0-rmse:3644.94779	validation_1-rmse:9247.11110
# [25]	validation_0-rmse:3612.71917	validation_1-rmse:9191.55025
# [26]	validation_0-rmse:3580.72676	validation_1-rmse:9138.34675
# [27]	validation_0-rmse:3549.13137	validation_1-rmse:9083.98672
# [28]	validation_0-rmse:3517.85902	validation_1-rmse:9030.42384
# [29]	validation_0-rmse:3486.90151	validation_1-rmse:8977.64538
# [30]	validation_0-rmse:3455.96997	validation_1-rmse:8926.78626
# [31]	validation_0-rmse:3425.62482	validation_1-rmse:8875.16352
# [32]	validation_0-rmse:3395.58750	validation_1-rmse:8824.30346
# [33]	validation_0-rmse:3365.85240	validation_1-rmse:8774.09368
# [34]	validation_0-rmse:3336.11201	validation_1-rmse:8725.91206
# [35]	validation_0-rmse:3307.01441	validation_1-rmse:8677.64929
# [36]	validation_0-rmse:3278.18098	validation_1-rmse:8630.04275
# [37]	validation_0-rmse:3249.29323	validation_1-rmse:8583.64588
# [38]	validation_0-rmse:3221.02154	validation_1-rmse:8537.36961
# [39]	validation_0-rmse:3193.03790	validation_1-rmse:8491.45680
# [40]	validation_0-rmse:3164.94697	validation_1-rmse:8444.92530
# [41]	validation_0-rmse:3137.50846	validation_1-rmse:8400.32795
# [42]	validation_0-rmse:3110.28178	validation_1-rmse:8356.93025
# [43]	validation_0-rmse:3083.40739	validation_1-rmse:8312.57802
# [44]	validation_0-rmse:3056.70663	validation_1-rmse:8268.58261
# [45]	validation_0-rmse:3030.33516	validation_1-rmse:8226.48686
# [46]	validation_0-rmse:3003.79857	validation_1-rmse:8183.25486
# [47]	validation_0-rmse:2977.88317	validation_1-rmse:8140.60218
# [48]	validation_0-rmse:2952.32717	validation_1-rmse:8098.51785
# [49]	validation_0-rmse:2926.89387	validation_1-rmse:8056.88044
# [50]	validation_0-rmse:2901.83792	validation_1-rmse:8016.03390
# [51]	validation_0-rmse:2876.90861	validation_1-rmse:7975.24789
# [52]	validation_0-rmse:2851.86762	validation_1-rmse:7937.92318
# [53]	validation_0-rmse:2827.21835	validation_1-rmse:7898.32943
# [54]	validation_0-rmse:2802.65963	validation_1-rmse:7862.01721
# [55]	validation_0-rmse:2778.34595	validation_1-rmse:7825.96948
# [56]	validation_0-rmse:2754.27528	validation_1-rmse:7790.42050
# [57]	validation_0-rmse:2730.44299	validation_1-rmse:7755.37672
# [58]	validation_0-rmse:2706.94485	validation_1-rmse:7718.31924
# [59]	validation_0-rmse:2683.57023	validation_1-rmse:7684.92292
# [60]	validation_0-rmse:2660.42745	validation_1-rmse:7651.53337
# [61]	validation_0-rmse:2637.51443	validation_1-rmse:7618.62978
# [62]	validation_0-rmse:2614.88930	validation_1-rmse:7584.09115
# [63]	validation_0-rmse:2592.41693	validation_1-rmse:7552.08603
# [64]	validation_0-rmse:2570.16808	validation_1-rmse:7520.54189
# [65]	validation_0-rmse:2548.19891	validation_1-rmse:7486.81847
# [66]	validation_0-rmse:2526.39460	validation_1-rmse:7456.52176
# [67]	validation_0-rmse:2504.80935	validation_1-rmse:7426.30107
# [68]	validation_0-rmse:2483.60656	validation_1-rmse:7394.57055
# [69]	validation_0-rmse:2462.41091	validation_1-rmse:7365.53797
# [70]	validation_0-rmse:2441.33441	validation_1-rmse:7336.57806
# [71]	validation_0-rmse:2420.33118	validation_1-rmse:7305.56644
# [72]	validation_0-rmse:2399.66707	validation_1-rmse:7277.50113
# [73]	validation_0-rmse:2379.06650	validation_1-rmse:7247.62372
# [74]	validation_0-rmse:2358.83384	validation_1-rmse:7220.31254
# [75]	validation_0-rmse:2338.60901	validation_1-rmse:7191.16399
# [76]	validation_0-rmse:2318.77290	validation_1-rmse:7164.92646
# [77]	validation_0-rmse:2298.94359	validation_1-rmse:7136.47045
# [78]	validation_0-rmse:2279.56713	validation_1-rmse:7112.70908
# [79]	validation_0-rmse:2260.21601	validation_1-rmse:7084.88952
# [80]	validation_0-rmse:2240.87733	validation_1-rmse:7070.73836
# [81]	validation_0-rmse:2222.03044	validation_1-rmse:7048.05787
# [82]	validation_0-rmse:2203.22925	validation_1-rmse:7023.35288
# [83]	validation_0-rmse:2184.47209	validation_1-rmse:6999.33891
# [84]	validation_0-rmse:2166.17281	validation_1-rmse:6975.63608
# [85]	validation_0-rmse:2147.76617	validation_1-rmse:6952.30925
# [86]	validation_0-rmse:2129.80216	validation_1-rmse:6931.29122
# [87]	validation_0-rmse:2111.75554	validation_1-rmse:6908.49309
# [88]	validation_0-rmse:2094.00817	validation_1-rmse:6884.03778
# [89]	validation_0-rmse:2076.56696	validation_1-rmse:6863.96800
# [90]	validation_0-rmse:2059.02985	validation_1-rmse:6842.16447
# [91]	validation_0-rmse:2041.87024	validation_1-rmse:6820.58453
# [92]	validation_0-rmse:2024.65155	validation_1-rmse:6797.66151
# [93]	validation_0-rmse:2007.73793	validation_1-rmse:6776.70972
# [94]	validation_0-rmse:1991.08518	validation_1-rmse:6756.14381
# [95]	validation_0-rmse:1974.43329	validation_1-rmse:6735.87206
# [96]	validation_0-rmse:1957.95814	validation_1-rmse:6714.09235
# [97]	validation_0-rmse:1941.65372	validation_1-rmse:6696.45564
# [98]	validation_0-rmse:1925.40804	validation_1-rmse:6676.57835
# [99]	validation_0-rmse:1909.39245	validation_1-rmse:6656.67728
# [100]	validation_0-rmse:1893.44501	validation_1-rmse:6637.98179
# [101]	validation_0-rmse:1877.72710	validation_1-rmse:6620.51368
# [102]	validation_0-rmse:1862.18771	validation_1-rmse:6603.31992
# [103]	validation_0-rmse:1846.69831	validation_1-rmse:6583.00978
# [104]	validation_0-rmse:1831.43285	validation_1-rmse:6566.37072
# [105]	validation_0-rmse:1816.11343	validation_1-rmse:6556.42350
# [106]	validation_0-rmse:1801.16245	validation_1-rmse:6540.18862
# [107]	validation_0-rmse:1786.37421	validation_1-rmse:6524.13268
# [108]	validation_0-rmse:1771.69592	validation_1-rmse:6506.78325
# [109]	validation_0-rmse:1757.02303	validation_1-rmse:6490.21597
# [110]	validation_0-rmse:1742.65089	validation_1-rmse:6474.89360
# [111]	validation_0-rmse:1728.18375	validation_1-rmse:6459.10275
# [112]	validation_0-rmse:1714.06059	validation_1-rmse:6442.86610
# [113]	validation_0-rmse:1699.92288	validation_1-rmse:6427.43209
# [114]	validation_0-rmse:1686.08823	validation_1-rmse:6413.09409
# [115]	validation_0-rmse:1672.20744	validation_1-rmse:6397.60153
# [116]	validation_0-rmse:1658.47927	validation_1-rmse:6382.86461
# [117]	validation_0-rmse:1644.86382	validation_1-rmse:6369.37283
# [118]	validation_0-rmse:1631.36895	validation_1-rmse:6355.16741
# [119]	validation_0-rmse:1618.01008	validation_1-rmse:6339.76006
# [120]	validation_0-rmse:1604.78234	validation_1-rmse:6326.09270
# [121]	validation_0-rmse:1591.80966	validation_1-rmse:6313.60052
# [122]	validation_0-rmse:1578.99548	validation_1-rmse:6301.32339
# [123]	validation_0-rmse:1566.13806	validation_1-rmse:6287.57191
# [124]	validation_0-rmse:1553.35533	validation_1-rmse:6274.94005
# [125]	validation_0-rmse:1540.74006	validation_1-rmse:6263.26272
# [126]	validation_0-rmse:1528.24571	validation_1-rmse:6250.86525
# [127]	validation_0-rmse:1515.87631	validation_1-rmse:6237.07957
# [128]	validation_0-rmse:1503.59374	validation_1-rmse:6225.14503
# [129]	validation_0-rmse:1491.45972	validation_1-rmse:6213.57925
# [130]	validation_0-rmse:1479.38455	validation_1-rmse:6202.25880
# [131]	validation_0-rmse:1467.61890	validation_1-rmse:6190.12242
# [132]	validation_0-rmse:1455.78077	validation_1-rmse:6179.03012
# [133]	validation_0-rmse:1444.04870	validation_1-rmse:6168.27322
# [134]	validation_0-rmse:1432.45263	validation_1-rmse:6156.77713
# [135]	validation_0-rmse:1420.99902	validation_1-rmse:6146.22579
# [136]	validation_0-rmse:1409.60671	validation_1-rmse:6135.92437
# [137]	validation_0-rmse:1398.37039	validation_1-rmse:6125.41862
# [138]	validation_0-rmse:1387.28473	validation_1-rmse:6114.79550
# [139]	validation_0-rmse:1376.26467	validation_1-rmse:6104.66723
# [140]	validation_0-rmse:1365.45092	validation_1-rmse:6095.83188
# [141]	validation_0-rmse:1354.54217	validation_1-rmse:6086.58507
# [142]	validation_0-rmse:1343.90022	validation_1-rmse:6075.53966
# [143]	validation_0-rmse:1333.24283	validation_1-rmse:6066.46897
# [144]	validation_0-rmse:1322.73850	validation_1-rmse:6057.19752
# [145]	validation_0-rmse:1312.41511	validation_1-rmse:6047.85536
# [146]	validation_0-rmse:1302.17348	validation_1-rmse:6038.41141
# [147]	validation_0-rmse:1291.85704	validation_1-rmse:6035.74812
# [148]	validation_0-rmse:1281.81416	validation_1-rmse:6027.11043
# [149]	validation_0-rmse:1271.75061	validation_1-rmse:6024.26227
# [150]	validation_0-rmse:1261.80376	validation_1-rmse:6021.47748
# [151]	validation_0-rmse:1252.06217	validation_1-rmse:6014.17783
# [152]	validation_0-rmse:1242.29911	validation_1-rmse:6011.52552
# [153]	validation_0-rmse:1232.74261	validation_1-rmse:6004.51689
# [154]	validation_0-rmse:1223.08940	validation_1-rmse:6002.04095
# [155]	validation_0-rmse:1213.72122	validation_1-rmse:5995.28476
# [156]	validation_0-rmse:1204.32754	validation_1-rmse:5993.33556
# [157]	validation_0-rmse:1194.96992	validation_1-rmse:5991.27516
# [158]	validation_0-rmse:1185.88124	validation_1-rmse:5983.50783
# [159]	validation_0-rmse:1176.80170	validation_1-rmse:5981.27113
# [160]	validation_0-rmse:1167.88071	validation_1-rmse:5974.87770
# [161]	validation_0-rmse:1158.87353	validation_1-rmse:5972.97265
# [162]	validation_0-rmse:1150.12533	validation_1-rmse:5966.78825
# [163]	validation_0-rmse:1141.26473	validation_1-rmse:5965.12646
# [164]	validation_0-rmse:1132.67881	validation_1-rmse:5959.35935
# [165]	validation_0-rmse:1123.97725	validation_1-rmse:5952.96540
# [166]	validation_0-rmse:1115.48665	validation_1-rmse:5951.19706
# [167]	validation_0-rmse:1107.15801	validation_1-rmse:5944.34283
# [168]	validation_0-rmse:1098.70272	validation_1-rmse:5943.09646
# [169]	validation_0-rmse:1090.52183	validation_1-rmse:5937.63613
# [170]	validation_0-rmse:1082.21118	validation_1-rmse:5931.91991
# [171]	validation_0-rmse:1074.18780	validation_1-rmse:5926.75880
# [172]	validation_0-rmse:1066.18258	validation_1-rmse:5925.51013
# [173]	validation_0-rmse:1058.31172	validation_1-rmse:5920.47508
# [174]	validation_0-rmse:1050.31060	validation_1-rmse:5913.81996
# [175]	validation_0-rmse:1042.39267	validation_1-rmse:5910.33491
# [176]	validation_0-rmse:1034.72043	validation_1-rmse:5907.36853
# [177]	validation_0-rmse:1026.94383	validation_1-rmse:5903.97557
# [178]	validation_0-rmse:1019.22433	validation_1-rmse:5898.68625
# [179]	validation_0-rmse:1011.52459	validation_1-rmse:5897.45964
# [180]	validation_0-rmse:1003.96306	validation_1-rmse:5894.15612
# [181]	validation_0-rmse:996.50737	validation_1-rmse:5893.15872
# [182]	validation_0-rmse:989.08431	validation_1-rmse:5889.92420
# [183]	validation_0-rmse:981.74088	validation_1-rmse:5886.85863
# [184]	validation_0-rmse:974.46391	validation_1-rmse:5885.82250
# [185]	validation_0-rmse:967.25805	validation_1-rmse:5882.75219
# [186]	validation_0-rmse:960.10823	validation_1-rmse:5879.80503
# [187]	validation_0-rmse:953.08962	validation_1-rmse:5879.03821
# [188]	validation_0-rmse:946.07936	validation_1-rmse:5876.25878
# [189]	validation_0-rmse:939.13954	validation_1-rmse:5875.24357
# [190]	validation_0-rmse:932.40875	validation_1-rmse:5873.05745
# [191]	validation_0-rmse:925.60748	validation_1-rmse:5870.35161
# [192]	validation_0-rmse:918.85830	validation_1-rmse:5867.63365
# [193]	validation_0-rmse:912.32737	validation_1-rmse:5865.58601
# [194]	validation_0-rmse:905.71431	validation_1-rmse:5862.99736
# [195]	validation_0-rmse:899.30291	validation_1-rmse:5861.03602
# [196]	validation_0-rmse:892.81116	validation_1-rmse:5858.56060
# [197]	validation_0-rmse:886.52587	validation_1-rmse:5856.65467
# [198]	validation_0-rmse:880.31725	validation_1-rmse:5854.83409
# [199]	validation_0-rmse:874.22650	validation_1-rmse:5852.95616
# [200]	validation_0-rmse:868.13153	validation_1-rmse:5849.76658
# [201]	validation_0-rmse:861.75787	validation_1-rmse:5848.15936
# [202]	validation_0-rmse:855.89712	validation_1-rmse:5845.00613
# [203]	validation_0-rmse:849.63408	validation_1-rmse:5843.73197
# [204]	validation_0-rmse:843.44780	validation_1-rmse:5842.53678
# [205]	validation_0-rmse:837.31711	validation_1-rmse:5839.72244
# [206]	validation_0-rmse:831.57715	validation_1-rmse:5838.18625
# [207]	validation_0-rmse:825.77069	validation_1-rmse:5835.23843
# [208]	validation_0-rmse:820.02912	validation_1-rmse:5833.28341
# [209]	validation_0-rmse:814.28279	validation_1-rmse:5833.46313
# [210]	validation_0-rmse:808.68154	validation_1-rmse:5832.16943
# [211]	validation_0-rmse:803.15246	validation_1-rmse:5827.25003
# [212]	validation_0-rmse:797.62451	validation_1-rmse:5825.61211
# [213]	validation_0-rmse:792.27973	validation_1-rmse:5824.28935
# [214]	validation_0-rmse:786.85854	validation_1-rmse:5822.67132
# [215]	validation_0-rmse:781.51365	validation_1-rmse:5820.31233
# [216]	validation_0-rmse:776.32263	validation_1-rmse:5819.07004
# [217]	validation_0-rmse:771.07963	validation_1-rmse:5817.56402
# [218]	validation_0-rmse:765.86768	validation_1-rmse:5814.98911
# [219]	validation_0-rmse:760.75979	validation_1-rmse:5810.57389
# [220]	validation_0-rmse:755.64280	validation_1-rmse:5809.14620
# [221]	validation_0-rmse:750.62632	validation_1-rmse:5808.13851
# [222]	validation_0-rmse:745.63337	validation_1-rmse:5807.00692
# [223]	validation_0-rmse:740.61555	validation_1-rmse:5804.17633
# [224]	validation_0-rmse:735.67974	validation_1-rmse:5803.01358
# [225]	validation_0-rmse:730.84264	validation_1-rmse:5801.06499
# [226]	validation_0-rmse:726.05677	validation_1-rmse:5799.93227
# [227]	validation_0-rmse:721.28592	validation_1-rmse:5798.12595
# [228]	validation_0-rmse:716.55684	validation_1-rmse:5796.52461
# [229]	validation_0-rmse:711.78453	validation_1-rmse:5793.78311
# [230]	validation_0-rmse:707.11046	validation_1-rmse:5792.34024
# [231]	validation_0-rmse:702.55595	validation_1-rmse:5791.25699
# [232]	validation_0-rmse:698.01129	validation_1-rmse:5790.07396
# [233]	validation_0-rmse:693.51302	validation_1-rmse:5789.10721
# [234]	validation_0-rmse:689.03280	validation_1-rmse:5787.72317
# [235]	validation_0-rmse:684.50433	validation_1-rmse:5785.18347
# [236]	validation_0-rmse:680.11435	validation_1-rmse:5783.77871
# [237]	validation_0-rmse:675.75703	validation_1-rmse:5782.37315
# [238]	validation_0-rmse:671.43182	validation_1-rmse:5779.34273
# [239]	validation_0-rmse:667.13530	validation_1-rmse:5776.53817
# [240]	validation_0-rmse:662.90512	validation_1-rmse:5773.64524
# [241]	validation_0-rmse:658.60396	validation_1-rmse:5771.33728
# [242]	validation_0-rmse:654.45793	validation_1-rmse:5768.57139
# [243]	validation_0-rmse:650.35064	validation_1-rmse:5765.83215
# [244]	validation_0-rmse:646.29912	validation_1-rmse:5763.27411
# [245]	validation_0-rmse:642.15399	validation_1-rmse:5761.13020
# [246]	validation_0-rmse:638.14518	validation_1-rmse:5758.56989
# [247]	validation_0-rmse:634.21893	validation_1-rmse:5756.16276
# [248]	validation_0-rmse:630.30527	validation_1-rmse:5753.71450
# [249]	validation_0-rmse:626.30524	validation_1-rmse:5751.67663
# [250]	validation_0-rmse:622.47533	validation_1-rmse:5750.83312
# [251]	validation_0-rmse:618.70587	validation_1-rmse:5749.86025
# [252]	validation_0-rmse:614.93866	validation_1-rmse:5748.92372
# [253]	validation_0-rmse:611.21822	validation_1-rmse:5748.18693
# [254]	validation_0-rmse:607.38526	validation_1-rmse:5746.28697
# [255]	validation_0-rmse:603.71319	validation_1-rmse:5745.44595
# [256]	validation_0-rmse:600.10443	validation_1-rmse:5744.59560
# [257]	validation_0-rmse:596.51622	validation_1-rmse:5743.82481
# [258]	validation_0-rmse:592.93890	validation_1-rmse:5743.01403
# [259]	validation_0-rmse:589.38738	validation_1-rmse:5742.23677
# [260]	validation_0-rmse:585.81429	validation_1-rmse:5740.61901
# [261]	validation_0-rmse:582.33030	validation_1-rmse:5739.90311
# [262]	validation_0-rmse:578.76632	validation_1-rmse:5738.48064
# [263]	validation_0-rmse:575.29775	validation_1-rmse:5736.96761
# [264]	validation_0-rmse:571.87400	validation_1-rmse:5736.33948
# [265]	validation_0-rmse:568.50779	validation_1-rmse:5735.74387
# [266]	validation_0-rmse:565.19596	validation_1-rmse:5735.17962
# [267]	validation_0-rmse:561.63100	validation_1-rmse:5733.45770
# [268]	validation_0-rmse:557.98708	validation_1-rmse:5732.79025
# [269]	validation_0-rmse:554.70525	validation_1-rmse:5731.49244
# [270]	validation_0-rmse:551.12632	validation_1-rmse:5730.88644
# [271]	validation_0-rmse:547.58440	validation_1-rmse:5730.31272
# [272]	validation_0-rmse:544.33141	validation_1-rmse:5729.16470
# [273]	validation_0-rmse:540.84514	validation_1-rmse:5728.65350
# [274]	validation_0-rmse:537.38480	validation_1-rmse:5728.24414
# [275]	validation_0-rmse:534.21988	validation_1-rmse:5727.10570
# [276]	validation_0-rmse:530.82945	validation_1-rmse:5726.67733
# [277]	validation_0-rmse:527.47465	validation_1-rmse:5726.23137
# [278]	validation_0-rmse:524.34791	validation_1-rmse:5725.19704
# [279]	validation_0-rmse:521.05024	validation_1-rmse:5724.85108
# [280]	validation_0-rmse:517.78748	validation_1-rmse:5724.48482
# [281]	validation_0-rmse:514.74291	validation_1-rmse:5723.53069
# [282]	validation_0-rmse:511.52054	validation_1-rmse:5723.33795
# [283]	validation_0-rmse:508.33929	validation_1-rmse:5723.06911
# [284]	validation_0-rmse:505.38136	validation_1-rmse:5722.19397
# [285]	validation_0-rmse:502.29395	validation_1-rmse:5722.06773
# [286]	validation_0-rmse:499.21373	validation_1-rmse:5721.98394
# [287]	validation_0-rmse:496.33428	validation_1-rmse:5721.18560
# [288]	validation_0-rmse:493.34344	validation_1-rmse:5721.14809
# [289]	validation_0-rmse:490.33998	validation_1-rmse:5721.06555
# [290]	validation_0-rmse:487.39770	validation_1-rmse:5721.06274
# [291]	validation_0-rmse:484.61656	validation_1-rmse:5720.37560
# [292]	validation_0-rmse:481.69347	validation_1-rmse:5720.35899
# [293]	validation_0-rmse:478.84340	validation_1-rmse:5720.36333
# [294]	validation_0-rmse:475.98246	validation_1-rmse:5720.32231
# [295]	validation_0-rmse:473.16709	validation_1-rmse:5720.24730
# [296]	validation_0-rmse:470.54176	validation_1-rmse:5719.76960
# [297]	validation_0-rmse:467.69246	validation_1-rmse:5719.89985
# [298]	validation_0-rmse:464.94824	validation_1-rmse:5719.88514
# [299]	validation_0-rmse:462.23059	validation_1-rmse:5719.82394
# [300]	validation_0-rmse:459.53635	validation_1-rmse:5719.79763
# [301]	validation_0-rmse:456.85152	validation_1-rmse:5719.87613
# [302]	validation_0-rmse:454.21458	validation_1-rmse:5719.92641
# [303]	validation_0-rmse:451.59978	validation_1-rmse:5720.05630
# [304]	validation_0-rmse:449.21322	validation_1-rmse:5719.72968
# [305]	validation_0-rmse:446.56905	validation_1-rmse:5719.93146
# [306]	validation_0-rmse:444.02006	validation_1-rmse:5720.10767
# [307]	validation_0-rmse:441.47739	validation_1-rmse:5720.17587
# [308]	validation_0-rmse:438.93670	validation_1-rmse:5720.36715
# [309]	validation_0-rmse:436.40257	validation_1-rmse:5720.65429
# [310]	validation_0-rmse:433.94896	validation_1-rmse:5720.82747
# [311]	validation_0-rmse:431.48585	validation_1-rmse:5721.01559
# [312]	validation_0-rmse:429.07828	validation_1-rmse:5720.86568
# [313]	validation_0-rmse:426.62381	validation_1-rmse:5721.16803
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=10,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=10000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
_ = plot_importance(reg_model, height=0.9 ,max_num_features = 10)

# %%
covid_test['forecast'] = reg_model.predict(X_test)

prophet_df_multi = pd.DataFrame(covid_df)

prophet_df_multi['forecast']=covid_test['forecast']

prophet_df_multi[['y', 'forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
graph_df = pd.DataFrame(covid_test)
graph_df['yhat'] = covid_test['forecast'].values
graph_df[['y','yhat']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
model_rmse = mean_squared_error(covid_test['y'], covid_test['forecast'], squared=False)
model_mae = mean_absolute_error(covid_test['y'], covid_test['forecast'])
print('Test RMSE: ', model_rmse)
print('Test MAE: ', model_mae)
print('MASE = ', mase(covid_test['y'], covid_test['forecast']))
# Out:
# Test RMSE:  5719.729652871059
# Test MAE:  2869.6887159587955
# MASE =  1.2143563510243423

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5, test_size = 100, gap = 1)
covid_df = covid_df.sort_index()

# %%
fig, axs = plt.subplots(5, 1, figsize=(10, 10), sharex=True)

fold = 0
for train_idx, val_idx in tss.split(covid_df):
    train = covid_df.iloc[train_idx]
    test = covid_df.iloc[val_idx]
    train['y'].plot(ax=axs[fold],
                          label='Training Set',
                          title=f'Data Train/Test Split Fold {fold}')
    test['y'].plot(ax=axs[fold],
                         label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold += 1
plt.show()

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=100, gap=1)
covid_df = covid_df.sort_index()


fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(covid_df):
    train = covid_df.iloc[train_idx]
    test = covid_df.iloc[val_idx]
    TARGET = 'y'

    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=1000,
                           early_stopping_rounds=20,
                           objective='reg:linear',
                           max_depth=3,
                           learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)

    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
# Out:
# [00:33:52] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1175.00116	validation_1-rmse:5453.89447
# [300]	validation_0-rmse:853.38994	validation_1-rmse:5280.65858
# [369]	validation_0-rmse:756.32734	validation_1-rmse:5275.91556
# [00:33:52] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1175.00116	validation_1-rmse:5453.89447
# [300]	validation_0-rmse:853.38994	validation_1-rmse:5280.65858
# [370]	validation_0-rmse:755.24788	validation_1-rmse:5275.34655
# [00:33:53] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1175.00116	validation_1-rmse:5453.89447
# [300]	validation_0-rmse:853.38994	validation_1-rmse:5280.65858
# [370]	validation_0-rmse:755.24788	validation_1-rmse:5275.34655
# [00:33:53] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1175.00116	validation_1-rmse:5453.89447
# [300]	validation_0-rmse:853.38994	validation_1-rmse:5280.65858
# [369]	validation_0-rmse:756.32734	validation_1-rmse:5275.91556
# [00:33:53] WARNING: c:\users\dev-admin\croot2\xgboost-split_1675461376218\work\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:4526.76424	validation_1-rmse:10802.96722
# [100]	validation_0-rmse:2033.72808	validation_1-rmse:6538.96004
# [200]	validation_0-rmse:1175.00116	validation_1-rmse:5453.89447
# [300]	validation_0-rmse:853.38994	validation_1-rmse:5280.65858
# [370]	validation_0-rmse:755.24788	validation_1-rmse:5275.34655

# %%
covid_test['forecast_1'] = reg.predict(X_test)

prophet_df_multi = pd.DataFrame(covid_df)

prophet_df_multi['forecast_1']=covid_test['forecast_1']

prophet_df_multi[['y', 'forecast_1']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
graph_df = pd.DataFrame(covid_test)
graph_df['yhat'] = covid_test['forecast_1'].values
graph_df[['y','yhat']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
model_rmse = mean_squared_error(covid_test['y'], covid_test['forecast'], squared=False)
model_mae = mean_absolute_error(covid_test['y'], covid_test['forecast'])
print('Test RMSE: ', model_rmse)
print('Test MAE: ', model_mae)
print('MASE = ', mase(covid_test['y'], covid_test['forecast']))
# Out:
# Test RMSE:  5719.729652871059
# Test MAE:  2869.6887159587955
# MASE =  1.2143563510243423
