# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")

covid_df = pd.read_csv('univariate_df.csv')
covid_df
# Out:
#             Date PROVINCE_STATE_NAME  PEOPLE_POSITIVE_NEW_CASES_COUNT
# 0     2020-01-21          California                                0
# 1     2020-01-22          California                                0
# 2     2020-01-23          California                                0
# 3     2020-01-24          California                                0
# 4     2020-01-25          California                                1
# ...          ...                 ...                              ...
# 8295  2022-04-25               Texas                             1243
# 8296  2022-04-26               Texas                             2556
# 8297  2022-04-27               Texas                             2513
# 8298  2022-04-28               Texas                             2715
# 8299  2022-04-29               Texas                             2823
#
# [8300 rows x 3 columns]

# %%
multi_df = pd.read_csv('covid_df__top_10.csv')
num_cols = multi_df._get_numeric_data().columns
print(num_cols, sep=',')
#print(num_cols.to_string())
# Out:
# Index(['STATE', 'Completeness_pct', 'Administered_Dose1_Recip',
#        'Administered_Dose1_Recip_5Plus', 'Administered_Dose1_Recip_12Plus',
#        'Administered_Dose1_Recip_18Plus', 'Administered_Dose1_Recip_65Plus',
#        'Series_Complete_Yes', 'Series_Complete_5Plus', 'Series_Complete_5to17',
#        ...
#        'AGE7579_MALE', 'AGE7579_FEM', 'AGE8084_TOT', 'AGE8084_MALE',
#        'AGE8084_FEM', 'AGE85PLUS_TOT', 'AGE85PLUS_MALE', 'AGE85PLUS_FEM',
#        'GDP_current_dollar', 'personal_income'],
#       dtype='object', length=161)

# %%
# For identifying hidden categorical variables
num_col = multi_df[num_cols]
for x in num_col.columns:
    if x != "PEOPLE_POSITIVE_CASES_COUNT":
        sns.barplot(x= x, y = "PEOPLE_POSITIVE_CASES_COUNT", data = multi_df)
        plt.show()
