# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")

# %%
covid_df = pd.read_csv('merged_df_ashv5.csv')
print(covid_df.shape)
covid_df.head(20)
# Out:
# (2555890, 181)
#           Date  Completeness_pct  Administered_Dose1_Recip  \
# 0   2020-01-21               NaN                       NaN
# 1   2020-01-21               NaN                       NaN
# 2   2020-01-21               NaN                       NaN
# 3   2020-01-21               NaN                       NaN
# 4   2020-01-21               NaN                       NaN
# 5   2020-01-21               NaN                       NaN
# 6   2020-01-21               NaN                       NaN
# 7   2020-01-21               NaN                       NaN
# 8   2020-01-21               NaN                       NaN
# 9   2020-01-21               NaN                       NaN
# 10  2020-01-21               NaN                       NaN
# 11  2020-01-21               NaN                       NaN
# 12  2020-01-21               NaN                       NaN
# 13  2020-01-21               NaN                       NaN
# 14  2020-01-21               NaN                       NaN
# 15  2020-01-21               NaN                       NaN
# 16  2020-01-21               NaN                       NaN
# 17  2020-01-21               NaN                       NaN
# 18  2020-01-21               NaN                       NaN
# 19  2020-01-21               NaN                       NaN
#
#     Administered_Dose1_Recip_5Plus  Administered_Dose1_Recip_12Plus  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
# 5                              NaN                              NaN
# 6                              NaN                              NaN
# 7                              NaN                              NaN
# 8                              NaN                              NaN
# 9                              NaN                              NaN
# 10                             NaN                              NaN
# 11                             NaN                              NaN
# 12                             NaN                              NaN
# 13                             NaN                              NaN
# 14                             NaN                              NaN
# 15                             NaN                              NaN
# 16                             NaN                              NaN
# 17                             NaN                              NaN
# 18                             NaN                              NaN
# 19                             NaN                              NaN
#
#     Administered_Dose1_Recip_18Plus  Administered_Dose1_Recip_65Plus  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8                               NaN                              NaN
# 9                               NaN                              NaN
# 10                              NaN                              NaN
# 11                              NaN                              NaN
# 12                              NaN                              NaN
# 13                              NaN                              NaN
# 14                              NaN                              NaN
# 15                              NaN                              NaN
# 16                              NaN                              NaN
# 17                              NaN                              NaN
# 18                              NaN                              NaN
# 19                              NaN                              NaN
#
#     Series_Complete_Yes  Series_Complete_5Plus  Series_Complete_5to17  ...  \
# 0                   NaN                    NaN                    NaN  ...
# 1                   NaN                    NaN                    NaN  ...
# 2                   NaN                    NaN                    NaN  ...
# 3                   NaN                    NaN                    NaN  ...
# 4                   NaN                    NaN                    NaN  ...
# 5                   NaN                    NaN                    NaN  ...
# 6                   NaN                    NaN                    NaN  ...
# 7                   NaN                    NaN                    NaN  ...
# 8                   NaN                    NaN                    NaN  ...
# 9                   NaN                    NaN                    NaN  ...
# 10                  NaN                    NaN                    NaN  ...
# 11                  NaN                    NaN                    NaN  ...
# 12                  NaN                    NaN                    NaN  ...
# 13                  NaN                    NaN                    NaN  ...
# 14                  NaN                    NaN                    NaN  ...
# 15                  NaN                    NaN                    NaN  ...
# 16                  NaN                    NaN                    NaN  ...
# 17                  NaN                    NaN                    NaN  ...
# 18                  NaN                    NaN                    NaN  ...
# 19                  NaN                    NaN                    NaN  ...
#
#     AGE8084_MALE  AGE8084_FEM  AGE85PLUS_TOT  AGE85PLUS_MALE  AGE85PLUS_FEM  \
# 0            112          122            169              80             89
# 1            232          246            444             136            308
# 2             65          105            107              41             66
# 3           2586         2657           4582            2129           2453
# 4            291          337            529             206            323
# 5             69          113            143              44             99
# 6            115          108            200              85            115
# 7            360          496            849             309            540
# 8            907         1243           2118             795           1323
# 9             43           53            162              51            111
# 10           211          262            402             156            246
# 11          1115         1539           2953            1014           1939
# 12           324          315            496             219            277
# 13          8800        10126          16633            6819           9814
# 14          1126         1473           2590             906           1684
# 15          3722         4642           7653            2729           4924
# 16          1655         2236           4045            1322           2723
# 17           126          179            303              94            209
# 18         13571        17461          36051           13327          22724
# 19           102          128            228              71            157
#
#     MEDIAN_AGE_TOT  MEDIAN_AGE_MALE  MEDIAN_AGE_FEM  GDP_current_dollar  \
# 0             36.9             36.1            37.5             1391880
# 1             53.0             56.4            44.7              387976
# 2             46.0             45.7            46.6              141553
# 3             38.8             37.9            39.8             7743796
# 4             42.2             42.0            42.6              750765
# 5             33.9             31.4            37.8              265515
# 6             40.7             40.2            41.8              782349
# 7             38.0             38.0            38.1             4553170
# 8             40.5             39.8            41.3             7007576
# 9             37.2             37.7            36.4              297666
# 10            45.1             44.7            45.5              533226
# 11            34.2             33.8            34.6            13264728
# 12            53.0             53.3            52.7              630550
# 13            40.0             38.9            41.0            30037406
# 14            38.7             37.5            39.9             6705769
# 15            38.7             37.9            39.6            23748680
# 16            40.4             39.4            41.4             8889241
# 17            41.2             39.9            43.0              520203
# 18            48.9             47.3            50.3            54399164
# 19            40.5             39.7            41.4              904075
#
#     personal_income
# 0             49571
# 1             30660
# 2             45270
# 3             45360
# 4             38304
# 5             40074
# 6             53517
# 7             62252
# 8             45759
# 9             50025
# 10            31846
# 11            54939
# 12            41848
# 13            40807
# 14            48916
# 15            57827
# 16            52951
# 17            43365
# 18            60721
# 19            44913
#
# [20 rows x 181 columns]

# %%
print(covid_df.columns.values, sep=',')
# Out:
# ['Date' 'Completeness_pct' 'Administered_Dose1_Recip'
#  'Administered_Dose1_Recip_5Plus' 'Administered_Dose1_Recip_12Plus'
#  'Administered_Dose1_Recip_18Plus' 'Administered_Dose1_Recip_65Plus'
#  'Series_Complete_Yes' 'Series_Complete_5Plus' 'Series_Complete_5to17'
#  'Series_Complete_12Plus' 'Series_Complete_18Plus'
#  'Series_Complete_65Plus' 'Booster_Doses' 'Booster_Doses_5Plus'
#  'Booster_Doses_12Plus' 'Booster_Doses_18Plus' 'Booster_Doses_50Plus'
#  'Booster_Doses_65Plus' 'Second_Booster_50Plus' 'Second_Booster_65Plus'
#  'SVI_CTGY' 'Metro_status' 'Series_Complete_Pop_Pct_UR_Equity'
#  'Series_Complete_5PlusPop_Pct_UR_Equity'
#  'Series_Complete_5to17Pop_Pct_UR_Equity'
#  'Series_Complete_12PlusPop_Pct_UR_Equity'
#  'Series_Complete_18PlusPop_Pct_UR_Equity'
#  'Series_Complete_65PlusPop_Pct_UR_Equity' 'Booster_Doses_Vax_Pct_SVI'
#  'Booster_Doses_12PlusVax_Pct_SVI' 'Booster_Doses_18PlusVax_Pct_SVI'
#  'Booster_Doses_65PlusVax_Pct_SVI' 'Booster_Doses_Vax_Pct_UR_Equity'
#  'Booster_Doses_12PlusVax_Pct_UR_Equity'
#  'Booster_Doses_18PlusVax_Pct_UR_Equity'
#  'Booster_Doses_65PlusVax_Pct_UR_Equity' 'Bivalent_Booster_5Plus'
#  'Bivalent_Booster_12Plus' 'Bivalent_Booster_18Plus'
#  'Bivalent_Booster_65Plus' 'STATE' 'PEOPLE_POSITIVE_CASES_COUNT'
#  'PEOPLE_DEATH_NEW_COUNT' 'PEOPLE_POSITIVE_NEW_CASES_COUNT'
#  'PEOPLE_DEATH_COUNT' 'TOT_POP' 'TOT_MALE' 'TOT_FEMALE' 'WA_MALE'
#  'WA_FEMALE' 'BA_MALE' 'BA_FEMALE' 'IA_MALE' 'IA_FEMALE' 'AA_MALE'
#  'AA_FEMALE' 'NA_MALE' 'NA_FEMALE' 'TOM_MALE' 'TOM_FEMALE' 'WAC_MALE'
#  'WAC_FEMALE' 'BAC_MALE' 'BAC_FEMALE' 'IAC_MALE' 'IAC_FEMALE' 'AAC_MALE'
#  'AAC_FEMALE' 'NAC_MALE' 'NAC_FEMALE' 'NH_MALE' 'NH_FEMALE' 'NHWA_MALE'
#  'NHWA_FEMALE' 'NHBA_MALE' 'NHBA_FEMALE' 'NHIA_MALE' 'NHIA_FEMALE'
#  'NHAA_MALE' 'NHAA_FEMALE' 'NHNA_MALE' 'NHNA_FEMALE' 'NHTOM_MALE'
#  'NHTOM_FEMALE' 'NHWAC_MALE' 'NHWAC_FEMALE' 'NHBAC_MALE' 'NHBAC_FEMALE'
#  'NHIAC_MALE' 'NHIAC_FEMALE' 'NHAAC_MALE' 'NHAAC_FEMALE' 'NHNAC_MALE'
#  'NHNAC_FEMALE' 'H_MALE' 'H_FEMALE' 'HWA_MALE' 'HWA_FEMALE' 'HBA_MALE'
#  'HBA_FEMALE' 'HIA_MALE' 'HIA_FEMALE' 'HAA_MALE' 'HAA_FEMALE' 'HNA_MALE'
#  'HNA_FEMALE' 'HTOM_MALE' 'HTOM_FEMALE' 'HWAC_MALE' 'HWAC_FEMALE'
#  'HBAC_MALE' 'HBAC_FEMALE' 'HIAC_MALE' 'HIAC_FEMALE' 'HAAC_MALE'
#  'HAAC_FEMALE' 'HNAC_MALE' 'HNAC_FEMALE' 'POPESTIMATE' 'POPEST_MALE'
#  'POPEST_FEM' 'AGE04_TOT' 'AGE04_MALE' 'AGE04_FEM' 'AGE59_TOT'
#  'AGE59_MALE' 'AGE59_FEM' 'AGE1014_TOT' 'AGE1014_MALE' 'AGE1014_FEM'
#  'AGE1519_TOT' 'AGE1519_MALE' 'AGE1519_FEM' 'AGE2024_TOT' 'AGE2024_MALE'
#  'AGE2024_FEM' 'AGE2529_TOT' 'AGE2529_MALE' 'AGE2529_FEM' 'AGE3034_TOT'
#  'AGE3034_MALE' 'AGE3034_FEM' 'AGE3539_TOT' 'AGE3539_MALE' 'AGE3539_FEM'
#  'AGE4044_TOT' 'AGE4044_MALE' 'AGE4044_FEM' 'AGE4549_TOT' 'AGE4549_MALE'
#  'AGE4549_FEM' 'AGE5054_TOT' 'AGE5054_MALE' 'AGE5054_FEM' 'AGE5559_TOT'
#  'AGE5559_MALE' 'AGE5559_FEM' 'AGE6064_TOT' 'AGE6064_MALE' 'AGE6064_FEM'
#  'AGE6569_TOT' 'AGE6569_MALE' 'AGE6569_FEM' 'AGE7074_TOT' 'AGE7074_MALE'
#  'AGE7074_FEM' 'AGE7579_TOT' 'AGE7579_MALE' 'AGE7579_FEM' 'AGE8084_TOT'
#  'AGE8084_MALE' 'AGE8084_FEM' 'AGE85PLUS_TOT' 'AGE85PLUS_MALE'
#  'AGE85PLUS_FEM' 'MEDIAN_AGE_TOT' 'MEDIAN_AGE_MALE' 'MEDIAN_AGE_FEM'
#  'GDP_current_dollar' 'personal_income']

# %%
missing = covid_df.isnull().sum()
print(missing.to_string())
# Out:
# Date                                             0
# Completeness_pct                            963040
# Administered_Dose1_Recip                   1007876
# Administered_Dose1_Recip_5Plus             2121838
# Administered_Dose1_Recip_12Plus            1057706
# Administered_Dose1_Recip_18Plus            1039754
# Administered_Dose1_Recip_65Plus            1039728
# Series_Complete_Yes                         964414
# Series_Complete_5Plus                      2105566
# Series_Complete_5to17                      2438822
# Series_Complete_12Plus                      982366
# Series_Complete_18Plus                      964414
# Series_Complete_65Plus                      964414
# Booster_Doses                              2125602
# Booster_Doses_5Plus                        2555890
# Booster_Doses_12Plus                       2261654
# Booster_Doses_18Plus                       2125602
# Booster_Doses_50Plus                       2125602
# Booster_Doses_65Plus                       2125602
# Second_Booster_50Plus                      2555890
# Second_Booster_65Plus                      2555890
# SVI_CTGY                                    961883
# Metro_status                                963392
# Series_Complete_Pop_Pct_UR_Equity          1159784
# Series_Complete_5PlusPop_Pct_UR_Equity     2106530
# Series_Complete_5to17Pop_Pct_UR_Equity     2438970
# Series_Complete_12PlusPop_Pct_UR_Equity    1174696
# Series_Complete_18PlusPop_Pct_UR_Equity    1159591
# Series_Complete_65PlusPop_Pct_UR_Equity    1160143
# Booster_Doses_Vax_Pct_SVI                  2438859
# Booster_Doses_12PlusVax_Pct_SVI            2438859
# Booster_Doses_18PlusVax_Pct_SVI            2438859
# Booster_Doses_65PlusVax_Pct_SVI            2438859
# Booster_Doses_Vax_Pct_UR_Equity            2438970
# Booster_Doses_12PlusVax_Pct_UR_Equity      2438970
# Booster_Doses_18PlusVax_Pct_UR_Equity      2438970
# Booster_Doses_65PlusVax_Pct_UR_Equity      2438970
# Bivalent_Booster_5Plus                     2555890
# Bivalent_Booster_12Plus                    2555890
# Bivalent_Booster_18Plus                    2555890
# Bivalent_Booster_65Plus                    2555890
# STATE                                            0
# PEOPLE_POSITIVE_CASES_COUNT                      0
# PEOPLE_DEATH_NEW_COUNT                           0
# PEOPLE_POSITIVE_NEW_CASES_COUNT                  0
# PEOPLE_DEATH_COUNT                               0
# TOT_POP                                          0
# TOT_MALE                                         0
# TOT_FEMALE                                       0
# WA_MALE                                          0
# WA_FEMALE                                        0
# BA_MALE                                          0
# BA_FEMALE                                        0
# IA_MALE                                          0
# IA_FEMALE                                        0
# AA_MALE                                          0
# AA_FEMALE                                        0
# NA_MALE                                          0
# NA_FEMALE                                        0
# TOM_MALE                                         0
# TOM_FEMALE                                       0
# WAC_MALE                                         0
# WAC_FEMALE                                       0
# BAC_MALE                                         0
# BAC_FEMALE                                       0
# IAC_MALE                                         0
# IAC_FEMALE                                       0
# AAC_MALE                                         0
# AAC_FEMALE                                       0
# NAC_MALE                                         0
# NAC_FEMALE                                       0
# NH_MALE                                          0
# NH_FEMALE                                        0
# NHWA_MALE                                        0
# NHWA_FEMALE                                      0
# NHBA_MALE                                        0
# NHBA_FEMALE                                      0
# NHIA_MALE                                        0
# NHIA_FEMALE                                      0
# NHAA_MALE                                        0
# NHAA_FEMALE                                      0
# NHNA_MALE                                        0
# NHNA_FEMALE                                      0
# NHTOM_MALE                                       0
# NHTOM_FEMALE                                     0
# NHWAC_MALE                                       0
# NHWAC_FEMALE                                     0
# NHBAC_MALE                                       0
# NHBAC_FEMALE                                     0
# NHIAC_MALE                                       0
# NHIAC_FEMALE                                     0
# NHAAC_MALE                                       0
# NHAAC_FEMALE                                     0
# NHNAC_MALE                                       0
# NHNAC_FEMALE                                     0
# H_MALE                                           0
# H_FEMALE                                         0
# HWA_MALE                                         0
# HWA_FEMALE                                       0
# HBA_MALE                                         0
# HBA_FEMALE                                       0
# HIA_MALE                                         0
# HIA_FEMALE                                       0
# HAA_MALE                                         0
# HAA_FEMALE                                       0
# HNA_MALE                                         0
# HNA_FEMALE                                       0
# HTOM_MALE                                        0
# HTOM_FEMALE                                      0
# HWAC_MALE                                        0
# HWAC_FEMALE                                      0
# HBAC_MALE                                        0
# HBAC_FEMALE                                      0
# HIAC_MALE                                        0
# HIAC_FEMALE                                      0
# HAAC_MALE                                        0
# HAAC_FEMALE                                      0
# HNAC_MALE                                        0
# HNAC_FEMALE                                      0
# POPESTIMATE                                      0
# POPEST_MALE                                      0
# POPEST_FEM                                       0
# AGE04_TOT                                        0
# AGE04_MALE                                       0
# AGE04_FEM                                        0
# AGE59_TOT                                        0
# AGE59_MALE                                       0
# AGE59_FEM                                        0
# AGE1014_TOT                                      0
# AGE1014_MALE                                     0
# AGE1014_FEM                                      0
# AGE1519_TOT                                      0
# AGE1519_MALE                                     0
# AGE1519_FEM                                      0
# AGE2024_TOT                                      0
# AGE2024_MALE                                     0
# AGE2024_FEM                                      0
# AGE2529_TOT                                      0
# AGE2529_MALE                                     0
# AGE2529_FEM                                      0
# AGE3034_TOT                                      0
# AGE3034_MALE                                     0
# AGE3034_FEM                                      0
# AGE3539_TOT                                      0
# AGE3539_MALE                                     0
# AGE3539_FEM                                      0
# AGE4044_TOT                                      0
# AGE4044_MALE                                     0
# AGE4044_FEM                                      0
# AGE4549_TOT                                      0
# AGE4549_MALE                                     0
# AGE4549_FEM                                      0
# AGE5054_TOT                                      0
# AGE5054_MALE                                     0
# AGE5054_FEM                                      0
# AGE5559_TOT                                      0
# AGE5559_MALE                                     0
# AGE5559_FEM                                      0
# AGE6064_TOT                                      0
# AGE6064_MALE                                     0
# AGE6064_FEM                                      0
# AGE6569_TOT                                      0
# AGE6569_MALE                                     0
# AGE6569_FEM                                      0
# AGE7074_TOT                                      0
# AGE7074_MALE                                     0
# AGE7074_FEM                                      0
# AGE7579_TOT                                      0
# AGE7579_MALE                                     0
# AGE7579_FEM                                      0
# AGE8084_TOT                                      0
# AGE8084_MALE                                     0
# AGE8084_FEM                                      0
# AGE85PLUS_TOT                                    0
# AGE85PLUS_MALE                                   0
# AGE85PLUS_FEM                                    0
# MEDIAN_AGE_TOT                                   0
# MEDIAN_AGE_MALE                                  0
# MEDIAN_AGE_FEM                                   0
# GDP_current_dollar                               0
# personal_income                                  0

# %%
num_cols = covid_df._get_numeric_data()
print(num_cols.columns.values, sep=',')
# Out:
# ['Completeness_pct' 'Administered_Dose1_Recip'
#  'Administered_Dose1_Recip_5Plus' 'Administered_Dose1_Recip_12Plus'
#  'Administered_Dose1_Recip_18Plus' 'Administered_Dose1_Recip_65Plus'
#  'Series_Complete_Yes' 'Series_Complete_5Plus' 'Series_Complete_5to17'
#  'Series_Complete_12Plus' 'Series_Complete_18Plus'
#  'Series_Complete_65Plus' 'Booster_Doses' 'Booster_Doses_5Plus'
#  'Booster_Doses_12Plus' 'Booster_Doses_18Plus' 'Booster_Doses_50Plus'
#  'Booster_Doses_65Plus' 'Second_Booster_50Plus' 'Second_Booster_65Plus'
#  'Series_Complete_Pop_Pct_UR_Equity'
#  'Series_Complete_5PlusPop_Pct_UR_Equity'
#  'Series_Complete_5to17Pop_Pct_UR_Equity'
#  'Series_Complete_12PlusPop_Pct_UR_Equity'
#  'Series_Complete_18PlusPop_Pct_UR_Equity'
#  'Series_Complete_65PlusPop_Pct_UR_Equity' 'Booster_Doses_Vax_Pct_SVI'
#  'Booster_Doses_12PlusVax_Pct_SVI' 'Booster_Doses_18PlusVax_Pct_SVI'
#  'Booster_Doses_65PlusVax_Pct_SVI' 'Booster_Doses_Vax_Pct_UR_Equity'
#  'Booster_Doses_12PlusVax_Pct_UR_Equity'
#  'Booster_Doses_18PlusVax_Pct_UR_Equity'
#  'Booster_Doses_65PlusVax_Pct_UR_Equity' 'Bivalent_Booster_5Plus'
#  'Bivalent_Booster_12Plus' 'Bivalent_Booster_18Plus'
#  'Bivalent_Booster_65Plus' 'STATE' 'PEOPLE_POSITIVE_CASES_COUNT'
#  'PEOPLE_DEATH_NEW_COUNT' 'PEOPLE_POSITIVE_NEW_CASES_COUNT'
#  'PEOPLE_DEATH_COUNT' 'TOT_POP' 'TOT_MALE' 'TOT_FEMALE' 'WA_MALE'
#  'WA_FEMALE' 'BA_MALE' 'BA_FEMALE' 'IA_MALE' 'IA_FEMALE' 'AA_MALE'
#  'AA_FEMALE' 'NA_MALE' 'NA_FEMALE' 'TOM_MALE' 'TOM_FEMALE' 'WAC_MALE'
#  'WAC_FEMALE' 'BAC_MALE' 'BAC_FEMALE' 'IAC_MALE' 'IAC_FEMALE' 'AAC_MALE'
#  'AAC_FEMALE' 'NAC_MALE' 'NAC_FEMALE' 'NH_MALE' 'NH_FEMALE' 'NHWA_MALE'
#  'NHWA_FEMALE' 'NHBA_MALE' 'NHBA_FEMALE' 'NHIA_MALE' 'NHIA_FEMALE'
#  'NHAA_MALE' 'NHAA_FEMALE' 'NHNA_MALE' 'NHNA_FEMALE' 'NHTOM_MALE'
#  'NHTOM_FEMALE' 'NHWAC_MALE' 'NHWAC_FEMALE' 'NHBAC_MALE' 'NHBAC_FEMALE'
#  'NHIAC_MALE' 'NHIAC_FEMALE' 'NHAAC_MALE' 'NHAAC_FEMALE' 'NHNAC_MALE'
#  'NHNAC_FEMALE' 'H_MALE' 'H_FEMALE' 'HWA_MALE' 'HWA_FEMALE' 'HBA_MALE'
#  'HBA_FEMALE' 'HIA_MALE' 'HIA_FEMALE' 'HAA_MALE' 'HAA_FEMALE' 'HNA_MALE'
#  'HNA_FEMALE' 'HTOM_MALE' 'HTOM_FEMALE' 'HWAC_MALE' 'HWAC_FEMALE'
#  'HBAC_MALE' 'HBAC_FEMALE' 'HIAC_MALE' 'HIAC_FEMALE' 'HAAC_MALE'
#  'HAAC_FEMALE' 'HNAC_MALE' 'HNAC_FEMALE' 'POPESTIMATE' 'POPEST_MALE'
#  'POPEST_FEM' 'AGE04_TOT' 'AGE04_MALE' 'AGE04_FEM' 'AGE59_TOT'
#  'AGE59_MALE' 'AGE59_FEM' 'AGE1014_TOT' 'AGE1014_MALE' 'AGE1014_FEM'
#  'AGE1519_TOT' 'AGE1519_MALE' 'AGE1519_FEM' 'AGE2024_TOT' 'AGE2024_MALE'
#  'AGE2024_FEM' 'AGE2529_TOT' 'AGE2529_MALE' 'AGE2529_FEM' 'AGE3034_TOT'
#  'AGE3034_MALE' 'AGE3034_FEM' 'AGE3539_TOT' 'AGE3539_MALE' 'AGE3539_FEM'
#  'AGE4044_TOT' 'AGE4044_MALE' 'AGE4044_FEM' 'AGE4549_TOT' 'AGE4549_MALE'
#  'AGE4549_FEM' 'AGE5054_TOT' 'AGE5054_MALE' 'AGE5054_FEM' 'AGE5559_TOT'
#  'AGE5559_MALE' 'AGE5559_FEM' 'AGE6064_TOT' 'AGE6064_MALE' 'AGE6064_FEM'
#  'AGE6569_TOT' 'AGE6569_MALE' 'AGE6569_FEM' 'AGE7074_TOT' 'AGE7074_MALE'
#  'AGE7074_FEM' 'AGE7579_TOT' 'AGE7579_MALE' 'AGE7579_FEM' 'AGE8084_TOT'
#  'AGE8084_MALE' 'AGE8084_FEM' 'AGE85PLUS_TOT' 'AGE85PLUS_MALE'
#  'AGE85PLUS_FEM' 'MEDIAN_AGE_TOT' 'MEDIAN_AGE_MALE' 'MEDIAN_AGE_FEM']

# %%
#Drop all States not in the Top 10
covid_df_uni_pre = covid_df.loc[covid_df['STATE'].isin([6, 48, 12, 36, 42, 17, 39, 13, 37, 26])]

# %%
#covid_df['Date'] = pd.to_datetime(covid_df['Date'])

# %%
#covid_df = covid_df.set_index('Date')
#covid_df.index = pd.to_datetime(covid_df.index)

# %%
#covid_df

# %%
covid_univariate_df = covid_df_uni_pre.loc[:, ['Date', 'STATE', 'PEOPLE_POSITIVE_NEW_CASES_COUNT']]
covid_univariate_df
# Out:
#                Date  STATE  PEOPLE_POSITIVE_NEW_CASES_COUNT
# 1        2020-01-21     39                                0
# 2        2020-01-21     17                                0
# 5        2020-01-21     48                                0
# 7        2020-01-21     39                                0
# 8        2020-01-21     36                                0
# ...             ...    ...                              ...
# 2555873  2022-04-29     37                                0
# 2555876  2022-04-29     12                                0
# 2555878  2022-04-29     37                                0
# 2555884  2022-04-29     36                               65
# 2555885  2022-04-29     39                                0
#
# [810910 rows x 3 columns]

# %%
covid_univariate_df.to_csv('covid_univariate_df.csv', index=False)
