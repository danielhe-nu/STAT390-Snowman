# %%
import pandas as pd
df_1 = pd.read_csv('feature_selection_top_states.csv', index_col = 'Date', parse_dates = True).drop(columns=['Unnamed: 0'])
df_2 = pd.read_csv('multivariate_eng_df.csv', index_col = 'Date', parse_dates=['Date']).drop(columns=['Unnamed: 0'])
df_2.head()
# Out:
#             STATE PROVINCE_STATE_NAME  Completeness_pct  \
# Date
# 2020-03-01      6          California               0.0
# 2020-03-02      6          California               0.0
# 2020-03-03      6          California               0.0
# 2020-03-04      6          California               0.0
# 2020-03-05      6          California               0.0
#
#             Administered_Dose1_Recip  Administered_Dose1_Recip_5Plus  \
# Date
# 2020-03-01                       0.0                             0.0
# 2020-03-02                       0.0                             0.0
# 2020-03-03                       0.0                             0.0
# 2020-03-04                       0.0                             0.0
# 2020-03-05                       0.0                             0.0
#
#             Administered_Dose1_Recip_12Plus  Administered_Dose1_Recip_18Plus  \
# Date
# 2020-03-01                              0.0                              0.0
# ...

# %%
df_1.head()
# Out:
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2020-03-01              1.0          1.0                                0.5
# 2020-03-02              1.0          1.0                                0.5
# 2020-03-03              1.0          1.0                                0.5
# 2020-03-04              1.0          1.0                                0.0
# 2020-03-05              1.0          1.0                                0.0
#
#             current_intensive_care_patients  facial_coverings  \
# Date
# 2020-03-01                            112.5               0.5
# 2020-03-02                            112.5               0.5
# 2020-03-03                            112.5               0.5
# 2020-03-04                            112.5               0.0
# 2020-03-05                            112.5               0.0
#
#             public_information_campaigns  testing_policy  income_support  \
# Date
# ...

# %%
# Filter rows where PEOPLE_POSITIVE_NEW_CASES_COUNT is negative
negative_cases_df = df_1[df_1['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0]
negative_cases_df
# Out:
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2021-06-30              2.0          2.0                                1.0
# 2021-06-04              1.0          1.0                                1.0
# 2021-01-18              1.0          2.0                                2.0
# 2022-02-08              2.0          2.0                                1.0
# 2021-11-28              1.0          1.0                                1.0
#
#             current_intensive_care_patients  facial_coverings  \
# Date
# 2021-06-30                            295.0               2.0
# 2021-06-04                            490.0               2.0
# 2021-01-18                            890.0               4.0
# 2022-02-08                            552.0               2.0
# 2021-11-28                            944.0               2.0
#
#             public_information_campaigns  testing_policy  income_support  \
# Date
# ...

# %%
# Filter rows where PEOPLE_POSITIVE_NEW_CASES_COUNT is negative
negative_cases_df_2 = df_2[df_2['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0]
print(negative_cases_df_2['PEOPLE_POSITIVE_NEW_CASES_COUNT'])
# Out:
# Date
# 2021-06-30    -1607
# 2021-06-04   -37566
# 2021-01-18     -263
# 2022-02-08    -4397
# 2021-11-28       -6
# Name: PEOPLE_POSITIVE_NEW_CASES_COUNT, dtype: int64

# %%
fl_df = df_1[df_1['PROVINCE_STATE_NAME'] == 'Florida']
ca_df = df_1[df_1['PROVINCE_STATE_NAME'] == 'California']
nc_df = df_1[df_1['PROVINCE_STATE_NAME'] == 'North Carolina']
pn_df = df_1[df_1['PROVINCE_STATE_NAME'] == 'Pennsylvania']
tx_df = df_1[df_1['PROVINCE_STATE_NAME'] == 'Texas']

# %%
# Find indices of rows with negative PEOPLE_POSITIVE_NEW_CASES_COUNT
negative_indices = fl_df[fl_df['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0].index

# Print rows surrounding negative values
for date in negative_indices:
    surrounding_dates = [date - pd.Timedelta(days=1), date, date + pd.Timedelta(days=1)]
    surrounding_rows = fl_df.loc[fl_df.index.intersection(surrounding_dates)]

x = pd.DataFrame(surrounding_rows)
x.head()
# Out:
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2021-06-03              1.0          1.0                                1.0
# 2021-06-04              1.0          1.0                                1.0
# 2021-06-05              1.0          1.0                                1.0
#
#             current_intensive_care_patients  facial_coverings  \
# Date
# 2021-06-03                            499.0               2.0
# 2021-06-04                            490.0               2.0
# 2021-06-05                            462.0               2.0
#
#             public_information_campaigns  testing_policy  income_support  \
# Date
# 2021-06-03                           2.0             3.0             1.0
# 2021-06-04                           2.0             3.0             1.0
# 2021-06-05                           2.0             3.0             1.0
#
#             public_transport_closing  new_cases_50_min  ...  NATIVE_PEOPLES  \
# ...

# %%
# Find indices of rows with negative PEOPLE_POSITIVE_NEW_CASES_COUNT
negative_indices = ca_df[ca_df['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0].index

# Print rows surrounding negative values
for date in negative_indices:
    surrounding_dates = [date - pd.Timedelta(days=1), date, date + pd.Timedelta(days=1)]
    surrounding_rows = ca_df.loc[ca_df.index.intersection(surrounding_dates)]

x = pd.DataFrame(surrounding_rows)
x.head()
# Out:
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2021-06-29              2.0          2.0                                1.0
# 2021-06-30              2.0          2.0                                1.0
# 2021-07-01              2.0          2.0                                1.0
#
#             current_intensive_care_patients  facial_coverings  \
# Date
# 2021-06-29                            300.0               2.0
# 2021-06-30                            295.0               2.0
# 2021-07-01                            285.0               2.0
#
#             public_information_campaigns  testing_policy  income_support  \
# Date
# 2021-06-29                           2.0             3.0             1.0
# 2021-06-30                           2.0             3.0             1.0
# 2021-07-01                           2.0             3.0             1.0
#
#             public_transport_closing  new_cases_50_min  ...  NATIVE_PEOPLES  \
# ...

# %%
# Find indices of rows with negative PEOPLE_POSITIVE_NEW_CASES_COUNT
negative_indices = nc_df[nc_df['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0].index

# Print rows surrounding negative values
for date in negative_indices:
    surrounding_dates = [date - pd.Timedelta(days=1), date, date + pd.Timedelta(days=1)]
    surrounding_rows = nc_df.loc[nc_df.index.intersection(surrounding_dates)]

x = pd.DataFrame(surrounding_rows)
x.head()
# Out:
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2021-01-17              1.0          2.0                                2.0
# 2021-01-18              1.0          2.0                                2.0
# 2021-01-19              1.0          2.0                                2.0
#
#             current_intensive_care_patients  facial_coverings  \
# Date
# 2021-01-17                            882.0               4.0
# 2021-01-18                            890.0               4.0
# 2021-01-19                            829.0               4.0
#
#             public_information_campaigns  testing_policy  income_support  \
# Date
# 2021-01-17                           2.0             2.0             1.0
# 2021-01-18                           2.0             2.0             1.0
# 2021-01-19                           2.0             2.0             1.0
#
#             public_transport_closing  new_cases_50_min  ...  NATIVE_PEOPLES  \
# ...

# %%
# Find indices of rows with negative PEOPLE_POSITIVE_NEW_CASES_COUNT
negative_indices = pn_df[pn_df['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0].index

# Print rows surrounding negative values
for date in negative_indices:
    surrounding_dates = [date - pd.Timedelta(days=1), date, date + pd.Timedelta(days=1)]
    surrounding_rows = pn_df.loc[pn_df.index.intersection(surrounding_dates)]

x = pd.DataFrame(surrounding_rows)
x.head()
# Out:
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2022-02-07              2.0          2.0                                1.0
# 2022-02-08              2.0          2.0                                1.0
# 2022-02-09              2.0          2.0                                1.0
#
#             current_intensive_care_patients  facial_coverings  \
# Date
# 2022-02-07                            594.0               2.0
# 2022-02-08                            552.0               2.0
# 2022-02-09                            539.0               2.0
#
#             public_information_campaigns  testing_policy  income_support  \
# Date
# 2022-02-07                           2.0             3.0             0.0
# 2022-02-08                           2.0             3.0             0.0
# 2022-02-09                           2.0             3.0             0.0
#
#             public_transport_closing  new_cases_50_min  ...  NATIVE_PEOPLES  \
# ...

# %%
# Find indices of rows with negative PEOPLE_POSITIVE_NEW_CASES_COUNT
negative_indices = tx_df[tx_df['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0].index

# Print rows surrounding negative values
for date in negative_indices:
    surrounding_dates = [date - pd.Timedelta(days=1), date, date + pd.Timedelta(days=1)]
    surrounding_rows = tx_df.loc[tx_df.index.intersection(surrounding_dates)]

x = pd.DataFrame(surrounding_rows)
x.head()
# Out:
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2021-11-27              1.0          1.0                                1.0
# 2021-11-28              1.0          1.0                                1.0
# 2021-11-29              1.0          1.0                                1.0
#
#             current_intensive_care_patients  facial_coverings  \
# Date
# 2021-11-27                            925.0               2.0
# 2021-11-28                            944.0               2.0
# 2021-11-29                            958.0               2.0
#
#             public_information_campaigns  testing_policy  income_support  \
# Date
# 2021-11-27                           2.0             3.0             1.0
# 2021-11-28                           2.0             3.0             1.0
# 2021-11-29                           2.0             3.0             1.0
#
#             public_transport_closing  new_cases_50_min  ...  NATIVE_PEOPLES  \
# ...

# %%
def correct_negative_values(df):
    df['PEOPLE_POSITIVE_NEW_CASES_COUNT'] = df['PEOPLE_POSITIVE_NEW_CASES_COUNT'].apply(lambda x: x*-1 if x < 0 else x)
    return df

# %%
fl_df_2 = correct_negative_values(fl_df)
fl_df_2.head()
# Out:
# /var/folders/4b/sl3y8zds5g52xl7kl2dsn52w0000gn/T/ipykernel_6467/3304331454.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PEOPLE_POSITIVE_NEW_CASES_COUNT'] = df['PEOPLE_POSITIVE_NEW_CASES_COUNT'].apply(lambda x: x*-1 if x < 0 else x)
#             contact_tracing  debt_relief  restrictions_on_internal_movement  \
# Date
# 2020-03-01              1.0          0.0                                0.0
# 2020-03-02              1.0          0.0                                0.0
# 2020-03-03              1.0          0.0                                0.0
# 2020-03-04              1.0          0.0                                0.0
# 2020-03-05              1.0          0.0                                0.0
#
# ...

# %%
# Find indices of rows with negative PEOPLE_POSITIVE_NEW_CASES_COUNT
negative_indices = fl_df_2[fl_df_2['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0].index

# Print rows surrounding negative values
for date in negative_indices:
    surrounding_dates = [date - pd.Timedelta(days=1), date, date + pd.Timedelta(days=1)]
    surrounding_rows = fl_df_2.loc[fl_df_2.index.intersection(surrounding_dates)]
    print(surrounding_rows)

# %%
fsts_2 = correct_negative_values(df_1)
mved_2 = correct_negative_values(df_2)

# %%
# Filter rows where PEOPLE_POSITIVE_NEW_CASES_COUNT is negative
negative_cases_df_3 = fsts_2[fsts_2['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0]
print(negative_cases_df_3['PEOPLE_POSITIVE_NEW_CASES_COUNT'])
# Out:
# Series([], Name: PEOPLE_POSITIVE_NEW_CASES_COUNT, dtype: int64)

# %%
# Filter rows where PEOPLE_POSITIVE_NEW_CASES_COUNT is negative
negative_cases_df_4 = mved_2[mved_2['PEOPLE_POSITIVE_NEW_CASES_COUNT'] < 0]
print(negative_cases_df_4['PEOPLE_POSITIVE_NEW_CASES_COUNT'])
# Out:
# Series([], Name: PEOPLE_POSITIVE_NEW_CASES_COUNT, dtype: int64)

# %%
fsts_2.shape
# Out:
# (7900, 52)

# %%
mved_2.shape
# Out:
# (7900, 180)

# %%
fsts_2.to_csv('feature_selection_top_states.csv')
mved_2.to_csv('multivariate_eng_df.csv')
